# %%
'''
Bibliotecas necesarias

! pip install pandas
! pip install requests
! pip install lxml
! pip install bs4
! pip install selenium

Fuente:

Dirección Meteorológica de Chile 2025/02

Catastro de estaciones
https://climatologia.meteochile.gob.cl/application/informacion/buscadorEstaciones

Conjunto por estación

urls_base = [
    "https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_ DiarioTs_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Humedad_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_PresionQFF_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Temperatura_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Viento_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Agua24Horas_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Agua6Horas_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_DiarioRR_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_PresionQFE_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_PuntoRocio_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_TMaxima_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_TMinima_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_IndiceUVB_"
]

'''

# %%
import requests
import pandas as pd
import time
import zipfile
import os

# %%
### Lectura de estaciones ### 

# Archivo descargado manualmente de manera previa desde página web y dejado en carpeta "data"
df = pd.read_html("data/CatastrodeEstacionesdelSistemaSACLIM_2025-02-16_21_13.xls")[0] # Requerirá actualización de path

lista_estaciones = df["Codigo Nacional"].values

print("Cantidad de estaciones:", len(lista_estaciones),"\n")
print(lista_estaciones,"\n")

df.head()
# Out:
# Cantidad de estaciones: 46
#
# [180005 200006 220002 230001 270001 270008 290004 320041 320051 330007
#  330019 330020 330021 330030 330031 330066 330077 330111 330112 330113
#  330163 340031 360011 360019 360042 370033 380029 390006 400009 410005
#  420014 430002 430004 430009 450001 450004 450005 460001 470001 510005
#  520006 530005 550001 950001 950002 950003]
#    NÂ°  Codigo Nacional     Codigo WIGOS Codigo OACI  \
# 0    0           180005  0-20000-0-85406        SCAR
# 1    1           200006  0-20000-0-85418        SCDA
# 2    2           220002  0-20000-0-85432        SCCF
# 3    3           230001  0-20000-0-85442        SCFA
# 4    4           270001  0-20000-0-85469        SCIP
#
#                          Nombre   Latitud   Longitud  Altitud (Mts)  \
# 0         Chacalluta, Arica Ap. -18.35555  -70.34028             51
# 1     Diego Aracena Iquique Ap. -20.54917  -70.18111             48
# 2            El Loa, Calama Ad. -22.49806  -68.89250           2321
# 3  Cerro Moreno Antofagasta Ap. -23.45361  -70.44528            139
# 4   Mataveri Isla de Pascua Ap. -27.15889 -109.43250             69
#
#   Propietario
# 0         DMC
# 1         DMC
# 2         DMC
# 3         DMC
# 4         DMC

# %%
 
# Selenium - Inicio de sesión en Página web y obtención de Cookie de acceso

# SECCIÓN REQUIERE INTERVENCIÓN MANUAL PARA INICIO DE SESIÓN

chromedriver_path = "selenium/chromedriver-win64/chromedriver.exe" # Puede requerir actualización

print("Iniciando selenium")

# Inicio de navegador
service = Service(chromedriver_path)
driver = webdriver.Chrome(service=service)
driver.get("https://climatologia.meteochile.gob.cl/application/usuario/loginUsuario")

##### NOTA : Aquí uno debe iniciar sesión manualmente. #####
print("Por favor, inicia sesión manualmente en navegador dentro de los próximos 30 segundos")

time.sleep(30)  # Ajustable según sea necesidad para iniciar sesión

# Captura de cookies #
cookies = driver.get_cookies()
print("Cookies capturadas:", cookies)

driver.quit()
# Out:
# Por favor, inicia sesión manualmente en la página que se abrió...
# Cookies capturadas: [{'domain': 'climatologia.meteochile.gob.cl', 'httpOnly': False, 'name': 'PHPSESSID', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '9i9o6oj0schochbuddf0k3699p'}]

# %%
### DESCARGA DE VISTAS ###

# Obtención de cookie desde JSON #
cookies_dict = {cookie["name"]: cookie["value"] for cookie in cookies}
print(cookies_dict)


data_folder = "data"
temp_folder = "temp"

# Crear carpeta data en caso de no existir
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

# URLS obtenidos 2025/02 desde climatologia.meteochile.gob.cl #
urls_base = [
    "https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_DiarioTs_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Humedad_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_PresionQFF_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Temperatura_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Viento_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Agua24Horas_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_Agua6Horas_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_DiarioRR_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_PresionQFE_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_PuntoRocio_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_TMaxima_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_TMinima_"
    ,"https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/*estacion*_XXXX_IndiceUVB_"
]

### Bucle de descarga ###

# Para cada URL de la lista #
for url in urls_base:
    # Para cada estación de la lista #
    for n in lista_estaciones:

        # Ajuste de url #
        dinamic_url = url.replace("*estacion*", str(n))
        print(dinamic_url)

        # Ajuste de nombre y path de archivo de salida #
        tema = url.split("_")[-2].rstrip("_/")
        nombre_archivo_zip = f"{temp_folder}\{str(n)}_{tema}.zip"
        
        ## Descarga de vista ##

        # Nota de desarrollo: Son alrededor de 400 vistas las descargadas, de las cuales alrededor de 7 fallan en su extracción
        # Se podría desarrollar a futuro una capacidad para asegurar la solidez de la descarga de datos

        try:
            # Solicitud HTTP a url dinámica utilizando cookie #
            response = requests.get(dinamic_url, cookies=cookies_dict)

            #response.raise_for_status()  # Lanza un error si la descarga falla
            time.sleep(2)

            # Escritura de respuesta binaria en .zip #
            with open(nombre_archivo_zip, "wb") as file:
                file.write(response.content)
            
            print(f"Descargado: {nombre_archivo_zip}\n")

            # Descomprimir el archivo ZIP #
            with zipfile.ZipFile(nombre_archivo_zip, 'r') as zip_ref:
                zip_ref.extractall(data_folder)
                print(f"Archivo descomprimido")

        except requests.exceptions.RequestException as e:
            print(f"Error al descargar {url}: {e} ###############################")
        except zipfile.BadZipFile:
            print(f"Error: El archivo descargado no es un archivo ZIP válido. ##########################")
# Out:
# {'PHPSESSID': '9i9o6oj0schochbuddf0k3699p'}
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_Humedad_
# Descargado: temp\180005_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_Humedad_
# Descargado: temp\200006_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_Humedad_
# Descargado: temp\220002_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_Humedad_
# Descargado: temp\230001_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_Humedad_
# Descargado: temp\270001_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_Humedad_
# Descargado: temp\270008_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_Humedad_
# Descargado: temp\290004_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_Humedad_
# Descargado: temp\320041_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_Humedad_
# Descargado: temp\320051_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_Humedad_
# Descargado: temp\330007_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_Humedad_
# Descargado: temp\330019_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_Humedad_
# Descargado: temp\330020_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_Humedad_
# Descargado: temp\330021_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_Humedad_
# Descargado: temp\330030_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_Humedad_
# Descargado: temp\330031_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_Humedad_
# Descargado: temp\330066_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_Humedad_
# Descargado: temp\330077_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_Humedad_
# Descargado: temp\330111_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_Humedad_
# Descargado: temp\330112_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_Humedad_
# Descargado: temp\330113_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_Humedad_
# Descargado: temp\330163_Humedad.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_Humedad_
# Descargado: temp\340031_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_Humedad_
# Descargado: temp\360011_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_Humedad_
# Descargado: temp\360019_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_Humedad_
# Descargado: temp\360042_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_Humedad_
# Descargado: temp\370033_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_Humedad_
# Descargado: temp\380029_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_Humedad_
# Descargado: temp\390006_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_Humedad_
# Descargado: temp\400009_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_Humedad_
# Descargado: temp\410005_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/420014_XXXX_Humedad_
# Descargado: temp\420014_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430002_XXXX_Humedad_
# Descargado: temp\430002_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430004_XXXX_Humedad_
# Descargado: temp\430004_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430009_XXXX_Humedad_
# Descargado: temp\430009_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450001_XXXX_Humedad_
# Descargado: temp\450001_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450004_XXXX_Humedad_
# Descargado: temp\450004_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450005_XXXX_Humedad_
# Descargado: temp\450005_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/460001_XXXX_Humedad_
# Descargado: temp\460001_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/470001_XXXX_Humedad_
# Descargado: temp\470001_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/510005_XXXX_Humedad_
# Descargado: temp\510005_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/520006_XXXX_Humedad_
# Descargado: temp\520006_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_Humedad_
# Descargado: temp\530005_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_Humedad_
# Descargado: temp\550001_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_Humedad_
# Descargado: temp\950001_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_Humedad_
# Descargado: temp\950002_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_Humedad_
# Descargado: temp\950003_Humedad.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_PresionQFF_
# Descargado: temp\180005_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_PresionQFF_
# Descargado: temp\200006_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_PresionQFF_
# Descargado: temp\220002_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_PresionQFF_
# Descargado: temp\230001_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_PresionQFF_
# Descargado: temp\270001_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_PresionQFF_
# Descargado: temp\270008_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_PresionQFF_
# Descargado: temp\290004_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_PresionQFF_
# Descargado: temp\320041_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_PresionQFF_
# Descargado: temp\320051_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_PresionQFF_
# Descargado: temp\330007_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_PresionQFF_
# Descargado: temp\330019_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_PresionQFF_
# Descargado: temp\330020_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_PresionQFF_
# Descargado: temp\330021_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_PresionQFF_
# Descargado: temp\330030_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_PresionQFF_
# Descargado: temp\330031_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_PresionQFF_
# Descargado: temp\330066_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_PresionQFF_
# Descargado: temp\330077_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_PresionQFF_
# Descargado: temp\330111_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_PresionQFF_
# Descargado: temp\330112_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_PresionQFF_
# Descargado: temp\330113_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_PresionQFF_
# Descargado: temp\330163_PresionQFF.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_PresionQFF_
# Descargado: temp\340031_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_PresionQFF_
# Descargado: temp\360011_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_PresionQFF_
# Descargado: temp\360019_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_PresionQFF_
# Descargado: temp\360042_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_PresionQFF_
# Descargado: temp\370033_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_PresionQFF_
# Descargado: temp\380029_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_PresionQFF_
# Descargado: temp\390006_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_PresionQFF_
# Descargado: temp\400009_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_PresionQFF_
# Descargado: temp\410005_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/420014_XXXX_PresionQFF_
# Descargado: temp\420014_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430002_XXXX_PresionQFF_
# Descargado: temp\430002_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430004_XXXX_PresionQFF_
# Descargado: temp\430004_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430009_XXXX_PresionQFF_
# Descargado: temp\430009_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450001_XXXX_PresionQFF_
# Descargado: temp\450001_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450004_XXXX_PresionQFF_
# Descargado: temp\450004_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450005_XXXX_PresionQFF_
# Descargado: temp\450005_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/460001_XXXX_PresionQFF_
# Descargado: temp\460001_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/470001_XXXX_PresionQFF_
# Descargado: temp\470001_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/510005_XXXX_PresionQFF_
# Descargado: temp\510005_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/520006_XXXX_PresionQFF_
# Descargado: temp\520006_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_PresionQFF_
# Descargado: temp\530005_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_PresionQFF_
# Descargado: temp\550001_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_PresionQFF_
# Descargado: temp\950001_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_PresionQFF_
# Descargado: temp\950002_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_PresionQFF_
# Descargado: temp\950003_PresionQFF.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_Temperatura_
# Descargado: temp\180005_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_Temperatura_
# Descargado: temp\200006_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_Temperatura_
# Descargado: temp\220002_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_Temperatura_
# Descargado: temp\230001_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_Temperatura_
# Descargado: temp\270001_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_Temperatura_
# Descargado: temp\270008_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_Temperatura_
# Descargado: temp\290004_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_Temperatura_
# Descargado: temp\320041_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_Temperatura_
# Descargado: temp\320051_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_Temperatura_
# Descargado: temp\330007_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_Temperatura_
# Descargado: temp\330019_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_Temperatura_
# Descargado: temp\330020_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_Temperatura_
# Descargado: temp\330021_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_Temperatura_
# Descargado: temp\330030_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_Temperatura_
# Descargado: temp\330031_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_Temperatura_
# Descargado: temp\330066_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_Temperatura_
# Descargado: temp\330077_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_Temperatura_
# Descargado: temp\330111_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_Temperatura_
# Descargado: temp\330112_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_Temperatura_
# Descargado: temp\330113_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_Temperatura_
# Descargado: temp\330163_Temperatura.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_Temperatura_
# Descargado: temp\340031_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_Temperatura_
# Descargado: temp\360011_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_Temperatura_
# Descargado: temp\360019_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_Temperatura_
# Descargado: temp\360042_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_Temperatura_
# Descargado: temp\370033_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_Temperatura_
# Descargado: temp\380029_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_Temperatura_
# Descargado: temp\390006_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_Temperatura_
# Descargado: temp\400009_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_Temperatura_
# Descargado: temp\410005_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/420014_XXXX_Temperatura_
# Descargado: temp\420014_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430002_XXXX_Temperatura_
# Descargado: temp\430002_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430004_XXXX_Temperatura_
# Descargado: temp\430004_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430009_XXXX_Temperatura_
# Descargado: temp\430009_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450001_XXXX_Temperatura_
# Descargado: temp\450001_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450004_XXXX_Temperatura_
# Descargado: temp\450004_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450005_XXXX_Temperatura_
# Descargado: temp\450005_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/460001_XXXX_Temperatura_
# Descargado: temp\460001_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/470001_XXXX_Temperatura_
# Descargado: temp\470001_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/510005_XXXX_Temperatura_
# Descargado: temp\510005_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/520006_XXXX_Temperatura_
# Descargado: temp\520006_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_Temperatura_
# Descargado: temp\530005_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_Temperatura_
# Descargado: temp\550001_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_Temperatura_
# Descargado: temp\950001_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_Temperatura_
# Descargado: temp\950002_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_Temperatura_
# Descargado: temp\950003_Temperatura.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_Viento_
# Descargado: temp\180005_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_Viento_
# Descargado: temp\200006_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_Viento_
# Descargado: temp\220002_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_Viento_
# Descargado: temp\230001_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_Viento_
# Descargado: temp\270001_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_Viento_
# Descargado: temp\270008_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_Viento_
# Descargado: temp\290004_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_Viento_
# Descargado: temp\320041_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_Viento_
# Descargado: temp\320051_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_Viento_
# Descargado: temp\330007_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_Viento_
# Descargado: temp\330019_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_Viento_
# Descargado: temp\330020_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_Viento_
# Descargado: temp\330021_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_Viento_
# Descargado: temp\330030_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_Viento_
# Descargado: temp\330031_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_Viento_
# Descargado: temp\330066_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_Viento_
# Descargado: temp\330077_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_Viento_
# Descargado: temp\330111_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_Viento_
# Descargado: temp\330112_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_Viento_
# Descargado: temp\330113_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_Viento_
# Descargado: temp\330163_Viento.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_Viento_
# Descargado: temp\340031_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_Viento_
# Descargado: temp\360011_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_Viento_
# Descargado: temp\360019_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_Viento_
# Descargado: temp\360042_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_Viento_
# Descargado: temp\370033_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_Viento_
# Descargado: temp\380029_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_Viento_
# Descargado: temp\390006_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_Viento_
# Descargado: temp\400009_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_Viento_
# Descargado: temp\410005_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/420014_XXXX_Viento_
# Descargado: temp\420014_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430002_XXXX_Viento_
# Descargado: temp\430002_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430004_XXXX_Viento_
# Descargado: temp\430004_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430009_XXXX_Viento_
# Descargado: temp\430009_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450001_XXXX_Viento_
# Descargado: temp\450001_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450004_XXXX_Viento_
# Descargado: temp\450004_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450005_XXXX_Viento_
# Descargado: temp\450005_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/460001_XXXX_Viento_
# Descargado: temp\460001_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/470001_XXXX_Viento_
# Descargado: temp\470001_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/510005_XXXX_Viento_
# Descargado: temp\510005_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/520006_XXXX_Viento_
# Descargado: temp\520006_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_Viento_
# Descargado: temp\530005_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_Viento_
# Descargado: temp\550001_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_Viento_
# Descargado: temp\950001_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_Viento_
# Descargado: temp\950002_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_Viento_
# Descargado: temp\950003_Viento.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_Agua24Horas_
# Descargado: temp\180005_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_Agua24Horas_
# Descargado: temp\200006_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_Agua24Horas_
# Descargado: temp\220002_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_Agua24Horas_
# Descargado: temp\230001_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_Agua24Horas_
# Descargado: temp\270001_Agua24Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_Agua24Horas_
# Descargado: temp\270008_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_Agua24Horas_
# Descargado: temp\290004_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_Agua24Horas_
# Descargado: temp\320041_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_Agua24Horas_
# Descargado: temp\320051_Agua24Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_Agua24Horas_
# Descargado: temp\330007_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_Agua24Horas_
# Descargado: temp\330019_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_Agua24Horas_
# Descargado: temp\330020_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_Agua24Horas_
# Descargado: temp\330021_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_Agua24Horas_
# Descargado: temp\330030_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_Agua24Horas_
# Descargado: temp\330031_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_Agua24Horas_
# Descargado: temp\330066_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_Agua24Horas_
# Descargado: temp\330077_Agua24Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_Agua24Horas_
# Descargado: temp\330111_Agua24Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_Agua24Horas_
# Descargado: temp\330112_Agua24Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_Agua24Horas_
# Descargado: temp\330113_Agua24Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_Agua24Horas_
# Descargado: temp\330163_Agua24Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_Agua24Horas_
# Descargado: temp\340031_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_Agua24Horas_
# Descargado: temp\360011_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_Agua24Horas_
# Descargado: temp\360019_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_Agua24Horas_
# Descargado: temp\360042_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_Agua24Horas_
# Descargado: temp\370033_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_Agua24Horas_
# Descargado: temp\380029_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_Agua24Horas_
# Descargado: temp\390006_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_Agua24Horas_
# Descargado: temp\400009_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_Agua24Horas_
# Descargado: temp\410005_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/420014_XXXX_Agua24Horas_
# Descargado: temp\420014_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430002_XXXX_Agua24Horas_
# Descargado: temp\430002_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430004_XXXX_Agua24Horas_
# Descargado: temp\430004_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430009_XXXX_Agua24Horas_
# Descargado: temp\430009_Agua24Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450001_XXXX_Agua24Horas_
# Descargado: temp\450001_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450004_XXXX_Agua24Horas_
# Descargado: temp\450004_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450005_XXXX_Agua24Horas_
# Descargado: temp\450005_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/460001_XXXX_Agua24Horas_
# Descargado: temp\460001_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/470001_XXXX_Agua24Horas_
# Descargado: temp\470001_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/510005_XXXX_Agua24Horas_
# Descargado: temp\510005_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/520006_XXXX_Agua24Horas_
# Descargado: temp\520006_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_Agua24Horas_
# Descargado: temp\530005_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_Agua24Horas_
# Descargado: temp\550001_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_Agua24Horas_
# Descargado: temp\950001_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_Agua24Horas_
# Descargado: temp\950002_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_Agua24Horas_
# Descargado: temp\950003_Agua24Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_Agua6Horas_
# Descargado: temp\180005_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_Agua6Horas_
# Descargado: temp\200006_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_Agua6Horas_
# Descargado: temp\220002_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_Agua6Horas_
# Descargado: temp\230001_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_Agua6Horas_
# Descargado: temp\270001_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_Agua6Horas_
# Descargado: temp\270008_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_Agua6Horas_
# Descargado: temp\290004_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_Agua6Horas_
# Descargado: temp\320041_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_Agua6Horas_
# Descargado: temp\320051_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_Agua6Horas_
# Descargado: temp\330007_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_Agua6Horas_
# Descargado: temp\330019_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_Agua6Horas_
# Descargado: temp\330020_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_Agua6Horas_
# Descargado: temp\330021_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_Agua6Horas_
# Descargado: temp\330030_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_Agua6Horas_
# Descargado: temp\330031_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_Agua6Horas_
# Descargado: temp\330066_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_Agua6Horas_
# Descargado: temp\330077_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_Agua6Horas_
# Descargado: temp\330111_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_Agua6Horas_
# Descargado: temp\330112_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_Agua6Horas_
# Descargado: temp\330113_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_Agua6Horas_
# Descargado: temp\330163_Agua6Horas.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_Agua6Horas_
# Descargado: temp\340031_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_Agua6Horas_
# Descargado: temp\360011_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_Agua6Horas_
# Descargado: temp\360019_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_Agua6Horas_
# Descargado: temp\360042_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_Agua6Horas_
# Descargado: temp\370033_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_Agua6Horas_
# Descargado: temp\380029_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_Agua6Horas_
# Descargado: temp\390006_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_Agua6Horas_
# Descargado: temp\400009_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_Agua6Horas_
# Descargado: temp\410005_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/420014_XXXX_Agua6Horas_
# Descargado: temp\420014_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430002_XXXX_Agua6Horas_
# Descargado: temp\430002_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430004_XXXX_Agua6Horas_
# Descargado: temp\430004_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430009_XXXX_Agua6Horas_
# Descargado: temp\430009_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450001_XXXX_Agua6Horas_
# Descargado: temp\450001_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450004_XXXX_Agua6Horas_
# Descargado: temp\450004_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450005_XXXX_Agua6Horas_
# Descargado: temp\450005_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/460001_XXXX_Agua6Horas_
# Descargado: temp\460001_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/470001_XXXX_Agua6Horas_
# Descargado: temp\470001_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/510005_XXXX_Agua6Horas_
# Descargado: temp\510005_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/520006_XXXX_Agua6Horas_
# Descargado: temp\520006_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_Agua6Horas_
# Descargado: temp\530005_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_Agua6Horas_
# Descargado: temp\550001_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_Agua6Horas_
# Descargado: temp\950001_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_Agua6Horas_
# Descargado: temp\950002_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_Agua6Horas_
# Descargado: temp\950003_Agua6Horas.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_DiarioRR_
# Descargado: temp\180005_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_DiarioRR_
# Descargado: temp\200006_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_DiarioRR_
# Descargado: temp\220002_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_DiarioRR_
# Descargado: temp\230001_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_DiarioRR_
# Descargado: temp\270001_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_DiarioRR_
# Descargado: temp\270008_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_DiarioRR_
# Descargado: temp\290004_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_DiarioRR_
# Descargado: temp\320041_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_DiarioRR_
# Descargado: temp\320051_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_DiarioRR_
# Descargado: temp\330007_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_DiarioRR_
# Descargado: temp\330019_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_DiarioRR_
# Descargado: temp\330020_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_DiarioRR_
# Descargado: temp\330021_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_DiarioRR_
# Descargado: temp\330030_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_DiarioRR_
# Descargado: temp\330031_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_DiarioRR_
# Descargado: temp\330066_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_DiarioRR_
# Descargado: temp\330077_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_DiarioRR_
# Descargado: temp\330111_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_DiarioRR_
# Descargado: temp\330112_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_DiarioRR_
# Descargado: temp\330113_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_DiarioRR_
# Descargado: temp\330163_DiarioRR.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_DiarioRR_
# Descargado: temp\340031_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_DiarioRR_
# Descargado: temp\360011_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_DiarioRR_
# Descargado: temp\360019_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_DiarioRR_
# Descargado: temp\360042_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_DiarioRR_
# Descargado: temp\370033_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_DiarioRR_
# Descargado: temp\380029_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_DiarioRR_
# Descargado: temp\390006_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_DiarioRR_
# Descargado: temp\400009_DiarioRR.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_DiarioRR_
# Descargado: temp\410005_DiarioRR.zip
# ...
# Descargado: temp\520006_TMaxima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_TMaxima_
# Descargado: temp\530005_TMaxima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_TMaxima_
# Descargado: temp\550001_TMaxima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_TMaxima_
# Descargado: temp\950001_TMaxima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_TMaxima_
# Descargado: temp\950002_TMaxima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_TMaxima_
# Descargado: temp\950003_TMaxima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_TMinima_
# Descargado: temp\180005_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_TMinima_
# Descargado: temp\200006_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_TMinima_
# Descargado: temp\220002_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_TMinima_
# Descargado: temp\230001_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_TMinima_
# Descargado: temp\270001_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_TMinima_
# Descargado: temp\270008_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_TMinima_
# Descargado: temp\290004_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_TMinima_
# Descargado: temp\320041_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_TMinima_
# Descargado: temp\320051_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_TMinima_
# Descargado: temp\330007_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_TMinima_
# Descargado: temp\330019_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_TMinima_
# Descargado: temp\330020_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_TMinima_
# Descargado: temp\330021_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_TMinima_
# Descargado: temp\330030_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_TMinima_
# Descargado: temp\330031_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_TMinima_
# Descargado: temp\330066_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_TMinima_
# Descargado: temp\330077_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_TMinima_
# Descargado: temp\330111_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_TMinima_
# Descargado: temp\330112_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_TMinima_
# Descargado: temp\330113_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_TMinima_
# Descargado: temp\330163_TMinima.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_TMinima_
# Descargado: temp\340031_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_TMinima_
# Descargado: temp\360011_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_TMinima_
# Descargado: temp\360019_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_TMinima_
# Descargado: temp\360042_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_TMinima_
# Descargado: temp\370033_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_TMinima_
# Descargado: temp\380029_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_TMinima_
# Descargado: temp\390006_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_TMinima_
# Descargado: temp\400009_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_TMinima_
# Descargado: temp\410005_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/420014_XXXX_TMinima_
# Descargado: temp\420014_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430002_XXXX_TMinima_
# Descargado: temp\430002_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430004_XXXX_TMinima_
# Descargado: temp\430004_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430009_XXXX_TMinima_
# Descargado: temp\430009_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450001_XXXX_TMinima_
# Descargado: temp\450001_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450004_XXXX_TMinima_
# Descargado: temp\450004_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450005_XXXX_TMinima_
# Descargado: temp\450005_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/460001_XXXX_TMinima_
# Descargado: temp\460001_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/470001_XXXX_TMinima_
# Descargado: temp\470001_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/510005_XXXX_TMinima_
# Descargado: temp\510005_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/520006_XXXX_TMinima_
# Descargado: temp\520006_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_TMinima_
# Descargado: temp\530005_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_TMinima_
# Descargado: temp\550001_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_TMinima_
# Descargado: temp\950001_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_TMinima_
# Descargado: temp\950002_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_TMinima_
# Descargado: temp\950003_TMinima.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/180005_XXXX_IndiceUVB_
# Descargado: temp\180005_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/200006_XXXX_IndiceUVB_
# Descargado: temp\200006_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/220002_XXXX_IndiceUVB_
# Descargado: temp\220002_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/230001_XXXX_IndiceUVB_
# Descargado: temp\230001_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270001_XXXX_IndiceUVB_
# Descargado: temp\270001_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/270008_XXXX_IndiceUVB_
# Descargado: temp\270008_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/290004_XXXX_IndiceUVB_
# Descargado: temp\290004_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320041_XXXX_IndiceUVB_
# Descargado: temp\320041_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/320051_XXXX_IndiceUVB_
# Descargado: temp\320051_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330007_XXXX_IndiceUVB_
# Descargado: temp\330007_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330019_XXXX_IndiceUVB_
# Descargado: temp\330019_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330020_XXXX_IndiceUVB_
# Descargado: temp\330020_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330021_XXXX_IndiceUVB_
# Descargado: temp\330021_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330030_XXXX_IndiceUVB_
# Descargado: temp\330030_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330031_XXXX_IndiceUVB_
# Descargado: temp\330031_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330066_XXXX_IndiceUVB_
# Descargado: temp\330066_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330077_XXXX_IndiceUVB_
# Descargado: temp\330077_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330111_XXXX_IndiceUVB_
# Descargado: temp\330111_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330112_XXXX_IndiceUVB_
# Descargado: temp\330112_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330113_XXXX_IndiceUVB_
# Descargado: temp\330113_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/330163_XXXX_IndiceUVB_
# Descargado: temp\330163_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/340031_XXXX_IndiceUVB_
# Descargado: temp\340031_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360011_XXXX_IndiceUVB_
# Descargado: temp\360011_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360019_XXXX_IndiceUVB_
# Descargado: temp\360019_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/360042_XXXX_IndiceUVB_
# Descargado: temp\360042_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/370033_XXXX_IndiceUVB_
# Descargado: temp\370033_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/380029_XXXX_IndiceUVB_
# Descargado: temp\380029_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/390006_XXXX_IndiceUVB_
# Descargado: temp\390006_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/400009_XXXX_IndiceUVB_
# Descargado: temp\400009_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/410005_XXXX_IndiceUVB_
# Descargado: temp\410005_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/420014_XXXX_IndiceUVB_
# Descargado: temp\420014_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430002_XXXX_IndiceUVB_
# Descargado: temp\430002_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430004_XXXX_IndiceUVB_
# Descargado: temp\430004_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/430009_XXXX_IndiceUVB_
# Descargado: temp\430009_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450001_XXXX_IndiceUVB_
# Descargado: temp\450001_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450004_XXXX_IndiceUVB_
# Descargado: temp\450004_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/450005_XXXX_IndiceUVB_
# Descargado: temp\450005_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/460001_XXXX_IndiceUVB_
# Descargado: temp\460001_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/470001_XXXX_IndiceUVB_
# Descargado: temp\470001_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/510005_XXXX_IndiceUVB_
# Descargado: temp\510005_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/520006_XXXX_IndiceUVB_
# Descargado: temp\520006_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/530005_XXXX_IndiceUVB_
# Descargado: temp\530005_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/550001_XXXX_IndiceUVB_
# Descargado: temp\550001_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950001_XXXX_IndiceUVB_
# Descargado: temp\950001_IndiceUVB.zip
# Archivo descomprimido
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950002_XXXX_IndiceUVB_
# Descargado: temp\950002_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.
# https://climatologia.meteochile.gob.cl/application/datos/getDatosSaclim/950003_XXXX_IndiceUVB_
# Descargado: temp\950003_IndiceUVB.zip
# Error: El archivo descargado no es un archivo ZIP válido.

# %% [markdown]
# ## Identificación de archivos descargados

# %%
lista_conceptos = [
    "DiarioTs", "Humedad", "PresionQFF", "Temperatura", "Viento",
    "Agua24Horas", "Agua6Horas", "DiarioRR", "PresionQFE",
    "PuntoRocio", "TMaxima", "TMinima", "IndiceUVB"
]

# Ruta de la carpeta "data"
carpeta_data = 'data'

# Diccionario para enlistar los archivos csv por concepto
# {
#  concepto1:[csv1,csv2]; 
#  concepto2:[csv1,csv2];...
# }

archivos_por_concepto = {concepto: [] for concepto in lista_conceptos}

# Clasificación de archivos recibidos por concepto #
# Para cada archivo en la capeta data #
for nombre_archivo in os.listdir(carpeta_data):

    # Verificar concepto por concepto el coincidente con el archivo #
    for concepto in lista_conceptos:
        if nombre_archivo.endswith(f'{concepto}_.csv'):

            # Construir el path completo del archivo y agregar a diccionario #
            path_completo = os.path.join(carpeta_data, nombre_archivo)
            archivos_por_concepto[concepto].append(path_completo)


# Mostrar el diccionario con las listas de archivos por concepto
for concepto, archivos in archivos_por_concepto.items():
    print("{")
    print(f"Concepto: {concepto}")
    print(f"Archivos: {archivos}")
    print(";")
    print("]")
# Out:
# Concepto: DiarioTs
# Archivos: ['data\\180005_XXXX_DiarioTs_.csv', 'data\\200006_XXXX_DiarioTs_.csv', 'data\\220002_XXXX_DiarioTs_.csv', 'data\\230001_XXXX_DiarioTs_.csv', 'data\\270001_XXXX_DiarioTs_.csv', 'data\\270008_XXXX_DiarioTs_.csv', 'data\\290004_XXXX_DiarioTs_.csv', 'data\\320041_XXXX_DiarioTs_.csv', 'data\\320051_XXXX_DiarioTs_.csv', 'data\\330007_XXXX_DiarioTs_.csv', 'data\\330019_XXXX_DiarioTs_.csv', 'data\\330020_XXXX_DiarioTs_.csv', 'data\\330021_XXXX_DiarioTs_.csv', 'data\\330030_XXXX_DiarioTs_.csv', 'data\\330031_XXXX_DiarioTs_.csv', 'data\\330066_XXXX_DiarioTs_.csv', 'data\\330077_XXXX_DiarioTs_.csv', 'data\\330111_XXXX_DiarioTs_.csv', 'data\\330112_XXXX_DiarioTs_.csv', 'data\\330113_XXXX_DiarioTs_.csv', 'data\\340031_XXXX_DiarioTs_.csv', 'data\\360011_XXXX_DiarioTs_.csv', 'data\\360019_XXXX_DiarioTs_.csv', 'data\\360042_XXXX_DiarioTs_.csv', 'data\\370033_XXXX_DiarioTs_.csv', 'data\\380029_XXXX_DiarioTs_.csv', 'data\\390006_XXXX_DiarioTs_.csv', 'data\\400009_XXXX_DiarioTs_.csv', 'data\\410005_XXXX_DiarioTs_.csv', 'data\\420014_XXXX_DiarioTs_.csv', 'data\\430002_XXXX_DiarioTs_.csv', 'data\\430004_XXXX_DiarioTs_.csv', 'data\\430009_XXXX_DiarioTs_.csv', 'data\\450001_XXXX_DiarioTs_.csv', 'data\\450004_XXXX_DiarioTs_.csv', 'data\\450005_XXXX_DiarioTs_.csv', 'data\\460001_XXXX_DiarioTs_.csv', 'data\\470001_XXXX_DiarioTs_.csv', 'data\\510005_XXXX_DiarioTs_.csv', 'data\\520006_XXXX_DiarioTs_.csv', 'data\\530005_XXXX_DiarioTs_.csv', 'data\\550001_XXXX_DiarioTs_.csv', 'data\\950001_XXXX_DiarioTs_.csv', 'data\\950002_XXXX_DiarioTs_.csv', 'data\\950003_XXXX_DiarioTs_.csv']
# ----------------------------------------
# Concepto: Humedad
# Archivos: ['data\\180005_XXXX_Humedad_.csv', 'data\\200006_XXXX_Humedad_.csv', 'data\\220002_XXXX_Humedad_.csv', 'data\\230001_XXXX_Humedad_.csv', 'data\\270001_XXXX_Humedad_.csv', 'data\\270008_XXXX_Humedad_.csv', 'data\\290004_XXXX_Humedad_.csv', 'data\\320041_XXXX_Humedad_.csv', 'data\\320051_XXXX_Humedad_.csv', 'data\\330007_XXXX_Humedad_.csv', 'data\\330019_XXXX_Humedad_.csv', 'data\\330020_XXXX_Humedad_.csv', 'data\\330021_XXXX_Humedad_.csv', 'data\\330030_XXXX_Humedad_.csv', 'data\\330031_XXXX_Humedad_.csv', 'data\\330066_XXXX_Humedad_.csv', 'data\\330077_XXXX_Humedad_.csv', 'data\\330111_XXXX_Humedad_.csv', 'data\\330112_XXXX_Humedad_.csv', 'data\\330113_XXXX_Humedad_.csv', 'data\\340031_XXXX_Humedad_.csv', 'data\\360011_XXXX_Humedad_.csv', 'data\\360019_XXXX_Humedad_.csv', 'data\\360042_XXXX_Humedad_.csv', 'data\\370033_XXXX_Humedad_.csv', 'data\\380029_XXXX_Humedad_.csv', 'data\\390006_XXXX_Humedad_.csv', 'data\\400009_XXXX_Humedad_.csv', 'data\\410005_XXXX_Humedad_.csv', 'data\\420014_XXXX_Humedad_.csv', 'data\\430002_XXXX_Humedad_.csv', 'data\\430004_XXXX_Humedad_.csv', 'data\\430009_XXXX_Humedad_.csv', 'data\\450001_XXXX_Humedad_.csv', 'data\\450004_XXXX_Humedad_.csv', 'data\\450005_XXXX_Humedad_.csv', 'data\\460001_XXXX_Humedad_.csv', 'data\\470001_XXXX_Humedad_.csv', 'data\\510005_XXXX_Humedad_.csv', 'data\\520006_XXXX_Humedad_.csv', 'data\\530005_XXXX_Humedad_.csv', 'data\\550001_XXXX_Humedad_.csv', 'data\\950001_XXXX_Humedad_.csv', 'data\\950002_XXXX_Humedad_.csv', 'data\\950003_XXXX_Humedad_.csv']
# ----------------------------------------
# Concepto: PresionQFF
# Archivos: ['data\\180005_XXXX_PresionQFF_.csv', 'data\\200006_XXXX_PresionQFF_.csv', 'data\\220002_XXXX_PresionQFF_.csv', 'data\\230001_XXXX_PresionQFF_.csv', 'data\\270001_XXXX_PresionQFF_.csv', 'data\\270008_XXXX_PresionQFF_.csv', 'data\\290004_XXXX_PresionQFF_.csv', 'data\\320041_XXXX_PresionQFF_.csv', 'data\\320051_XXXX_PresionQFF_.csv', 'data\\330007_XXXX_PresionQFF_.csv', 'data\\330019_XXXX_PresionQFF_.csv', 'data\\330020_XXXX_PresionQFF_.csv', 'data\\330021_XXXX_PresionQFF_.csv', 'data\\330030_XXXX_PresionQFF_.csv', 'data\\330031_XXXX_PresionQFF_.csv', 'data\\330066_XXXX_PresionQFF_.csv', 'data\\330077_XXXX_PresionQFF_.csv', 'data\\330111_XXXX_PresionQFF_.csv', 'data\\330112_XXXX_PresionQFF_.csv', 'data\\330113_XXXX_PresionQFF_.csv', 'data\\340031_XXXX_PresionQFF_.csv', 'data\\360011_XXXX_PresionQFF_.csv', 'data\\360019_XXXX_PresionQFF_.csv', 'data\\360042_XXXX_PresionQFF_.csv', 'data\\370033_XXXX_PresionQFF_.csv', 'data\\380029_XXXX_PresionQFF_.csv', 'data\\390006_XXXX_PresionQFF_.csv', 'data\\400009_XXXX_PresionQFF_.csv', 'data\\410005_XXXX_PresionQFF_.csv', 'data\\420014_XXXX_PresionQFF_.csv', 'data\\430002_XXXX_PresionQFF_.csv', 'data\\430004_XXXX_PresionQFF_.csv', 'data\\430009_XXXX_PresionQFF_.csv', 'data\\450001_XXXX_PresionQFF_.csv', 'data\\450004_XXXX_PresionQFF_.csv', 'data\\450005_XXXX_PresionQFF_.csv', 'data\\460001_XXXX_PresionQFF_.csv', 'data\\470001_XXXX_PresionQFF_.csv', 'data\\510005_XXXX_PresionQFF_.csv', 'data\\520006_XXXX_PresionQFF_.csv', 'data\\530005_XXXX_PresionQFF_.csv', 'data\\550001_XXXX_PresionQFF_.csv', 'data\\950001_XXXX_PresionQFF_.csv', 'data\\950002_XXXX_PresionQFF_.csv', 'data\\950003_XXXX_PresionQFF_.csv']
# ----------------------------------------
# Concepto: Temperatura
# Archivos: ['data\\180005_XXXX_Temperatura_.csv', 'data\\200006_XXXX_Temperatura_.csv', 'data\\220002_XXXX_Temperatura_.csv', 'data\\230001_XXXX_Temperatura_.csv', 'data\\270001_XXXX_Temperatura_.csv', 'data\\270008_XXXX_Temperatura_.csv', 'data\\290004_XXXX_Temperatura_.csv', 'data\\320041_XXXX_Temperatura_.csv', 'data\\320051_XXXX_Temperatura_.csv', 'data\\330007_XXXX_Temperatura_.csv', 'data\\330019_XXXX_Temperatura_.csv', 'data\\330020_XXXX_Temperatura_.csv', 'data\\330021_XXXX_Temperatura_.csv', 'data\\330030_XXXX_Temperatura_.csv', 'data\\330031_XXXX_Temperatura_.csv', 'data\\330066_XXXX_Temperatura_.csv', 'data\\330077_XXXX_Temperatura_.csv', 'data\\330111_XXXX_Temperatura_.csv', 'data\\330112_XXXX_Temperatura_.csv', 'data\\330113_XXXX_Temperatura_.csv', 'data\\340031_XXXX_Temperatura_.csv', 'data\\360011_XXXX_Temperatura_.csv', 'data\\360019_XXXX_Temperatura_.csv', 'data\\360042_XXXX_Temperatura_.csv', 'data\\370033_XXXX_Temperatura_.csv', 'data\\380029_XXXX_Temperatura_.csv', 'data\\390006_XXXX_Temperatura_.csv', 'data\\400009_XXXX_Temperatura_.csv', 'data\\410005_XXXX_Temperatura_.csv', 'data\\420014_XXXX_Temperatura_.csv', 'data\\430002_XXXX_Temperatura_.csv', 'data\\430004_XXXX_Temperatura_.csv', 'data\\430009_XXXX_Temperatura_.csv', 'data\\450001_XXXX_Temperatura_.csv', 'data\\450004_XXXX_Temperatura_.csv', 'data\\450005_XXXX_Temperatura_.csv', 'data\\460001_XXXX_Temperatura_.csv', 'data\\470001_XXXX_Temperatura_.csv', 'data\\510005_XXXX_Temperatura_.csv', 'data\\520006_XXXX_Temperatura_.csv', 'data\\530005_XXXX_Temperatura_.csv', 'data\\550001_XXXX_Temperatura_.csv', 'data\\950001_XXXX_Temperatura_.csv', 'data\\950002_XXXX_Temperatura_.csv', 'data\\950003_XXXX_Temperatura_.csv']
# ----------------------------------------
# Concepto: Viento
# Archivos: ['data\\180005_XXXX_Viento_.csv', 'data\\200006_XXXX_Viento_.csv', 'data\\220002_XXXX_Viento_.csv', 'data\\230001_XXXX_Viento_.csv', 'data\\270001_XXXX_Viento_.csv', 'data\\270008_XXXX_Viento_.csv', 'data\\290004_XXXX_Viento_.csv', 'data\\320041_XXXX_Viento_.csv', 'data\\320051_XXXX_Viento_.csv', 'data\\330007_XXXX_Viento_.csv', 'data\\330019_XXXX_Viento_.csv', 'data\\330020_XXXX_Viento_.csv', 'data\\330021_XXXX_Viento_.csv', 'data\\330030_XXXX_Viento_.csv', 'data\\330031_XXXX_Viento_.csv', 'data\\330066_XXXX_Viento_.csv', 'data\\330077_XXXX_Viento_.csv', 'data\\330111_XXXX_Viento_.csv', 'data\\330112_XXXX_Viento_.csv', 'data\\330113_XXXX_Viento_.csv', 'data\\340031_XXXX_Viento_.csv', 'data\\360011_XXXX_Viento_.csv', 'data\\360019_XXXX_Viento_.csv', 'data\\360042_XXXX_Viento_.csv', 'data\\370033_XXXX_Viento_.csv', 'data\\380029_XXXX_Viento_.csv', 'data\\390006_XXXX_Viento_.csv', 'data\\400009_XXXX_Viento_.csv', 'data\\410005_XXXX_Viento_.csv', 'data\\420014_XXXX_Viento_.csv', 'data\\430002_XXXX_Viento_.csv', 'data\\430004_XXXX_Viento_.csv', 'data\\430009_XXXX_Viento_.csv', 'data\\450001_XXXX_Viento_.csv', 'data\\450004_XXXX_Viento_.csv', 'data\\450005_XXXX_Viento_.csv', 'data\\460001_XXXX_Viento_.csv', 'data\\470001_XXXX_Viento_.csv', 'data\\510005_XXXX_Viento_.csv', 'data\\520006_XXXX_Viento_.csv', 'data\\530005_XXXX_Viento_.csv', 'data\\550001_XXXX_Viento_.csv', 'data\\950001_XXXX_Viento_.csv', 'data\\950002_XXXX_Viento_.csv', 'data\\950003_XXXX_Viento_.csv']
# ----------------------------------------
# Concepto: Agua24Horas
# Archivos: ['data\\180005_XXXX_Agua24Horas_.csv', 'data\\200006_XXXX_Agua24Horas_.csv', 'data\\220002_XXXX_Agua24Horas_.csv', 'data\\230001_XXXX_Agua24Horas_.csv', 'data\\270008_XXXX_Agua24Horas_.csv', 'data\\290004_XXXX_Agua24Horas_.csv', 'data\\320041_XXXX_Agua24Horas_.csv', 'data\\330007_XXXX_Agua24Horas_.csv', 'data\\330019_XXXX_Agua24Horas_.csv', 'data\\330020_XXXX_Agua24Horas_.csv', 'data\\330021_XXXX_Agua24Horas_.csv', 'data\\330030_XXXX_Agua24Horas_.csv', 'data\\330031_XXXX_Agua24Horas_.csv', 'data\\330066_XXXX_Agua24Horas_.csv', 'data\\340031_XXXX_Agua24Horas_.csv', 'data\\360011_XXXX_Agua24Horas_.csv', 'data\\360019_XXXX_Agua24Horas_.csv', 'data\\360042_XXXX_Agua24Horas_.csv', 'data\\370033_XXXX_Agua24Horas_.csv', 'data\\380029_XXXX_Agua24Horas_.csv', 'data\\390006_XXXX_Agua24Horas_.csv', 'data\\400009_XXXX_Agua24Horas_.csv', 'data\\410005_XXXX_Agua24Horas_.csv', 'data\\420014_XXXX_Agua24Horas_.csv', 'data\\430002_XXXX_Agua24Horas_.csv', 'data\\430004_XXXX_Agua24Horas_.csv', 'data\\450001_XXXX_Agua24Horas_.csv', 'data\\450004_XXXX_Agua24Horas_.csv', 'data\\450005_XXXX_Agua24Horas_.csv', 'data\\460001_XXXX_Agua24Horas_.csv', 'data\\470001_XXXX_Agua24Horas_.csv', 'data\\510005_XXXX_Agua24Horas_.csv', 'data\\520006_XXXX_Agua24Horas_.csv', 'data\\530005_XXXX_Agua24Horas_.csv', 'data\\550001_XXXX_Agua24Horas_.csv', 'data\\950001_XXXX_Agua24Horas_.csv', 'data\\950002_XXXX_Agua24Horas_.csv', 'data\\950003_XXXX_Agua24Horas_.csv']
# ----------------------------------------
# Concepto: Agua6Horas
# Archivos: ['data\\180005_XXXX_Agua6Horas_.csv', 'data\\200006_XXXX_Agua6Horas_.csv', 'data\\220002_XXXX_Agua6Horas_.csv', 'data\\230001_XXXX_Agua6Horas_.csv', 'data\\270001_XXXX_Agua6Horas_.csv', 'data\\270008_XXXX_Agua6Horas_.csv', 'data\\290004_XXXX_Agua6Horas_.csv', 'data\\320041_XXXX_Agua6Horas_.csv', 'data\\320051_XXXX_Agua6Horas_.csv', 'data\\330007_XXXX_Agua6Horas_.csv', 'data\\330019_XXXX_Agua6Horas_.csv', 'data\\330020_XXXX_Agua6Horas_.csv', 'data\\330021_XXXX_Agua6Horas_.csv', 'data\\330030_XXXX_Agua6Horas_.csv', 'data\\330031_XXXX_Agua6Horas_.csv', 'data\\330066_XXXX_Agua6Horas_.csv', 'data\\330077_XXXX_Agua6Horas_.csv', 'data\\330111_XXXX_Agua6Horas_.csv', 'data\\330112_XXXX_Agua6Horas_.csv', 'data\\330113_XXXX_Agua6Horas_.csv', 'data\\340031_XXXX_Agua6Horas_.csv', 'data\\360011_XXXX_Agua6Horas_.csv', 'data\\360019_XXXX_Agua6Horas_.csv', 'data\\360042_XXXX_Agua6Horas_.csv', 'data\\370033_XXXX_Agua6Horas_.csv', 'data\\380029_XXXX_Agua6Horas_.csv', 'data\\390006_XXXX_Agua6Horas_.csv', 'data\\400009_XXXX_Agua6Horas_.csv', 'data\\410005_XXXX_Agua6Horas_.csv', 'data\\420014_XXXX_Agua6Horas_.csv', 'data\\430002_XXXX_Agua6Horas_.csv', 'data\\430004_XXXX_Agua6Horas_.csv', 'data\\430009_XXXX_Agua6Horas_.csv', 'data\\450001_XXXX_Agua6Horas_.csv', 'data\\450004_XXXX_Agua6Horas_.csv', 'data\\450005_XXXX_Agua6Horas_.csv', 'data\\460001_XXXX_Agua6Horas_.csv', 'data\\470001_XXXX_Agua6Horas_.csv', 'data\\510005_XXXX_Agua6Horas_.csv', 'data\\520006_XXXX_Agua6Horas_.csv', 'data\\530005_XXXX_Agua6Horas_.csv', 'data\\550001_XXXX_Agua6Horas_.csv', 'data\\950001_XXXX_Agua6Horas_.csv', 'data\\950002_XXXX_Agua6Horas_.csv', 'data\\950003_XXXX_Agua6Horas_.csv']
# ----------------------------------------
# Concepto: DiarioRR
# Archivos: ['data\\180005_XXXX_DiarioRR_.csv', 'data\\200006_XXXX_DiarioRR_.csv', 'data\\220002_XXXX_DiarioRR_.csv', 'data\\230001_XXXX_DiarioRR_.csv', 'data\\270001_XXXX_DiarioRR_.csv', 'data\\270008_XXXX_DiarioRR_.csv', 'data\\290004_XXXX_DiarioRR_.csv', 'data\\320041_XXXX_DiarioRR_.csv', 'data\\320051_XXXX_DiarioRR_.csv', 'data\\330007_XXXX_DiarioRR_.csv', 'data\\330019_XXXX_DiarioRR_.csv', 'data\\330020_XXXX_DiarioRR_.csv', 'data\\330021_XXXX_DiarioRR_.csv', 'data\\330030_XXXX_DiarioRR_.csv', 'data\\330031_XXXX_DiarioRR_.csv', 'data\\330066_XXXX_DiarioRR_.csv', 'data\\330077_XXXX_DiarioRR_.csv', 'data\\330111_XXXX_DiarioRR_.csv', 'data\\330112_XXXX_DiarioRR_.csv', 'data\\330113_XXXX_DiarioRR_.csv', 'data\\340031_XXXX_DiarioRR_.csv', 'data\\360011_XXXX_DiarioRR_.csv', 'data\\360019_XXXX_DiarioRR_.csv', 'data\\360042_XXXX_DiarioRR_.csv', 'data\\370033_XXXX_DiarioRR_.csv', 'data\\380029_XXXX_DiarioRR_.csv', 'data\\390006_XXXX_DiarioRR_.csv', 'data\\400009_XXXX_DiarioRR_.csv', 'data\\410005_XXXX_DiarioRR_.csv', 'data\\420014_XXXX_DiarioRR_.csv', 'data\\430002_XXXX_DiarioRR_.csv', 'data\\430004_XXXX_DiarioRR_.csv', 'data\\430009_XXXX_DiarioRR_.csv', 'data\\450001_XXXX_DiarioRR_.csv', 'data\\450004_XXXX_DiarioRR_.csv', 'data\\450005_XXXX_DiarioRR_.csv', 'data\\460001_XXXX_DiarioRR_.csv', 'data\\470001_XXXX_DiarioRR_.csv', 'data\\510005_XXXX_DiarioRR_.csv', 'data\\520006_XXXX_DiarioRR_.csv', 'data\\530005_XXXX_DiarioRR_.csv', 'data\\550001_XXXX_DiarioRR_.csv', 'data\\950001_XXXX_DiarioRR_.csv', 'data\\950002_XXXX_DiarioRR_.csv', 'data\\950003_XXXX_DiarioRR_.csv']
# ----------------------------------------
# Concepto: PresionQFE
# Archivos: ['data\\180005_XXXX_PresionQFE_.csv', 'data\\200006_XXXX_PresionQFE_.csv', 'data\\220002_XXXX_PresionQFE_.csv', 'data\\230001_XXXX_PresionQFE_.csv', 'data\\270001_XXXX_PresionQFE_.csv', 'data\\270008_XXXX_PresionQFE_.csv', 'data\\290004_XXXX_PresionQFE_.csv', 'data\\320041_XXXX_PresionQFE_.csv', 'data\\320051_XXXX_PresionQFE_.csv', 'data\\330007_XXXX_PresionQFE_.csv', 'data\\330019_XXXX_PresionQFE_.csv', 'data\\330020_XXXX_PresionQFE_.csv', 'data\\330021_XXXX_PresionQFE_.csv', 'data\\330030_XXXX_PresionQFE_.csv', 'data\\330031_XXXX_PresionQFE_.csv', 'data\\330066_XXXX_PresionQFE_.csv', 'data\\330077_XXXX_PresionQFE_.csv', 'data\\330111_XXXX_PresionQFE_.csv', 'data\\330112_XXXX_PresionQFE_.csv', 'data\\330113_XXXX_PresionQFE_.csv', 'data\\340031_XXXX_PresionQFE_.csv', 'data\\360011_XXXX_PresionQFE_.csv', 'data\\360019_XXXX_PresionQFE_.csv', 'data\\360042_XXXX_PresionQFE_.csv', 'data\\370033_XXXX_PresionQFE_.csv', 'data\\380029_XXXX_PresionQFE_.csv', 'data\\390006_XXXX_PresionQFE_.csv', 'data\\400009_XXXX_PresionQFE_.csv', 'data\\410005_XXXX_PresionQFE_.csv', 'data\\420014_XXXX_PresionQFE_.csv', 'data\\430002_XXXX_PresionQFE_.csv', 'data\\430004_XXXX_PresionQFE_.csv', 'data\\430009_XXXX_PresionQFE_.csv', 'data\\450001_XXXX_PresionQFE_.csv', 'data\\450004_XXXX_PresionQFE_.csv', 'data\\450005_XXXX_PresionQFE_.csv', 'data\\460001_XXXX_PresionQFE_.csv', 'data\\470001_XXXX_PresionQFE_.csv', 'data\\510005_XXXX_PresionQFE_.csv', 'data\\520006_XXXX_PresionQFE_.csv', 'data\\530005_XXXX_PresionQFE_.csv', 'data\\550001_XXXX_PresionQFE_.csv', 'data\\950001_XXXX_PresionQFE_.csv', 'data\\950002_XXXX_PresionQFE_.csv', 'data\\950003_XXXX_PresionQFE_.csv']
# ----------------------------------------
# Concepto: PuntoRocio
# Archivos: ['data\\180005_XXXX_PuntoRocio_.csv', 'data\\200006_XXXX_PuntoRocio_.csv', 'data\\220002_XXXX_PuntoRocio_.csv', 'data\\230001_XXXX_PuntoRocio_.csv', 'data\\270001_XXXX_PuntoRocio_.csv', 'data\\270008_XXXX_PuntoRocio_.csv', 'data\\290004_XXXX_PuntoRocio_.csv', 'data\\320041_XXXX_PuntoRocio_.csv', 'data\\320051_XXXX_PuntoRocio_.csv', 'data\\330007_XXXX_PuntoRocio_.csv', 'data\\330019_XXXX_PuntoRocio_.csv', 'data\\330020_XXXX_PuntoRocio_.csv', 'data\\330021_XXXX_PuntoRocio_.csv', 'data\\330030_XXXX_PuntoRocio_.csv', 'data\\330031_XXXX_PuntoRocio_.csv', 'data\\330066_XXXX_PuntoRocio_.csv', 'data\\330077_XXXX_PuntoRocio_.csv', 'data\\330111_XXXX_PuntoRocio_.csv', 'data\\330112_XXXX_PuntoRocio_.csv', 'data\\330113_XXXX_PuntoRocio_.csv', 'data\\340031_XXXX_PuntoRocio_.csv', 'data\\360011_XXXX_PuntoRocio_.csv', 'data\\360019_XXXX_PuntoRocio_.csv', 'data\\360042_XXXX_PuntoRocio_.csv', 'data\\370033_XXXX_PuntoRocio_.csv', 'data\\380029_XXXX_PuntoRocio_.csv', 'data\\390006_XXXX_PuntoRocio_.csv', 'data\\400009_XXXX_PuntoRocio_.csv', 'data\\410005_XXXX_PuntoRocio_.csv', 'data\\420014_XXXX_PuntoRocio_.csv', 'data\\430002_XXXX_PuntoRocio_.csv', 'data\\430004_XXXX_PuntoRocio_.csv', 'data\\430009_XXXX_PuntoRocio_.csv', 'data\\450001_XXXX_PuntoRocio_.csv', 'data\\450004_XXXX_PuntoRocio_.csv', 'data\\450005_XXXX_PuntoRocio_.csv', 'data\\460001_XXXX_PuntoRocio_.csv', 'data\\470001_XXXX_PuntoRocio_.csv', 'data\\510005_XXXX_PuntoRocio_.csv', 'data\\520006_XXXX_PuntoRocio_.csv', 'data\\530005_XXXX_PuntoRocio_.csv', 'data\\550001_XXXX_PuntoRocio_.csv', 'data\\950001_XXXX_PuntoRocio_.csv', 'data\\950002_XXXX_PuntoRocio_.csv', 'data\\950003_XXXX_PuntoRocio_.csv']
# ----------------------------------------
# Concepto: TMaxima
# Archivos: ['data\\180005_XXXX_TMaxima_.csv', 'data\\200006_XXXX_TMaxima_.csv', 'data\\220002_XXXX_TMaxima_.csv', 'data\\230001_XXXX_TMaxima_.csv', 'data\\270001_XXXX_TMaxima_.csv', 'data\\270008_XXXX_TMaxima_.csv', 'data\\290004_XXXX_TMaxima_.csv', 'data\\320041_XXXX_TMaxima_.csv', 'data\\320051_XXXX_TMaxima_.csv', 'data\\330007_XXXX_TMaxima_.csv', 'data\\330019_XXXX_TMaxima_.csv', 'data\\330020_XXXX_TMaxima_.csv', 'data\\330021_XXXX_TMaxima_.csv', 'data\\330030_XXXX_TMaxima_.csv', 'data\\330031_XXXX_TMaxima_.csv', 'data\\330066_XXXX_TMaxima_.csv', 'data\\330077_XXXX_TMaxima_.csv', 'data\\330111_XXXX_TMaxima_.csv', 'data\\330112_XXXX_TMaxima_.csv', 'data\\330113_XXXX_TMaxima_.csv', 'data\\340031_XXXX_TMaxima_.csv', 'data\\360011_XXXX_TMaxima_.csv', 'data\\360019_XXXX_TMaxima_.csv', 'data\\360042_XXXX_TMaxima_.csv', 'data\\370033_XXXX_TMaxima_.csv', 'data\\380029_XXXX_TMaxima_.csv', 'data\\390006_XXXX_TMaxima_.csv', 'data\\400009_XXXX_TMaxima_.csv', 'data\\410005_XXXX_TMaxima_.csv', 'data\\420014_XXXX_TMaxima_.csv', 'data\\430002_XXXX_TMaxima_.csv', 'data\\430004_XXXX_TMaxima_.csv', 'data\\430009_XXXX_TMaxima_.csv', 'data\\450001_XXXX_TMaxima_.csv', 'data\\450004_XXXX_TMaxima_.csv', 'data\\450005_XXXX_TMaxima_.csv', 'data\\460001_XXXX_TMaxima_.csv', 'data\\470001_XXXX_TMaxima_.csv', 'data\\510005_XXXX_TMaxima_.csv', 'data\\520006_XXXX_TMaxima_.csv', 'data\\530005_XXXX_TMaxima_.csv', 'data\\550001_XXXX_TMaxima_.csv', 'data\\950001_XXXX_TMaxima_.csv', 'data\\950002_XXXX_TMaxima_.csv', 'data\\950003_XXXX_TMaxima_.csv']
# ----------------------------------------
# Concepto: TMinima
# Archivos: ['data\\180005_XXXX_TMinima_.csv', 'data\\200006_XXXX_TMinima_.csv', 'data\\220002_XXXX_TMinima_.csv', 'data\\230001_XXXX_TMinima_.csv', 'data\\270001_XXXX_TMinima_.csv', 'data\\270008_XXXX_TMinima_.csv', 'data\\290004_XXXX_TMinima_.csv', 'data\\320041_XXXX_TMinima_.csv', 'data\\320051_XXXX_TMinima_.csv', 'data\\330007_XXXX_TMinima_.csv', 'data\\330019_XXXX_TMinima_.csv', 'data\\330020_XXXX_TMinima_.csv', 'data\\330021_XXXX_TMinima_.csv', 'data\\330030_XXXX_TMinima_.csv', 'data\\330031_XXXX_TMinima_.csv', 'data\\330066_XXXX_TMinima_.csv', 'data\\330077_XXXX_TMinima_.csv', 'data\\330111_XXXX_TMinima_.csv', 'data\\330112_XXXX_TMinima_.csv', 'data\\330113_XXXX_TMinima_.csv', 'data\\340031_XXXX_TMinima_.csv', 'data\\360011_XXXX_TMinima_.csv', 'data\\360019_XXXX_TMinima_.csv', 'data\\360042_XXXX_TMinima_.csv', 'data\\370033_XXXX_TMinima_.csv', 'data\\380029_XXXX_TMinima_.csv', 'data\\390006_XXXX_TMinima_.csv', 'data\\400009_XXXX_TMinima_.csv', 'data\\410005_XXXX_TMinima_.csv', 'data\\420014_XXXX_TMinima_.csv', 'data\\430002_XXXX_TMinima_.csv', 'data\\430004_XXXX_TMinima_.csv', 'data\\430009_XXXX_TMinima_.csv', 'data\\450001_XXXX_TMinima_.csv', 'data\\450004_XXXX_TMinima_.csv', 'data\\450005_XXXX_TMinima_.csv', 'data\\460001_XXXX_TMinima_.csv', 'data\\470001_XXXX_TMinima_.csv', 'data\\510005_XXXX_TMinima_.csv', 'data\\520006_XXXX_TMinima_.csv', 'data\\530005_XXXX_TMinima_.csv', 'data\\550001_XXXX_TMinima_.csv', 'data\\950001_XXXX_TMinima_.csv', 'data\\950002_XXXX_TMinima_.csv', 'data\\950003_XXXX_TMinima_.csv']
# ----------------------------------------
# Concepto: IndiceUVB
# Archivos: ['data\\200006_XXXX_IndiceUVB_.csv', 'data\\230001_XXXX_IndiceUVB_.csv', 'data\\270001_XXXX_IndiceUVB_.csv', 'data\\270008_XXXX_IndiceUVB_.csv', 'data\\290004_XXXX_IndiceUVB_.csv', 'data\\330020_XXXX_IndiceUVB_.csv', 'data\\330021_XXXX_IndiceUVB_.csv', 'data\\330077_XXXX_IndiceUVB_.csv', 'data\\340031_XXXX_IndiceUVB_.csv', 'data\\360011_XXXX_IndiceUVB_.csv', 'data\\360019_XXXX_IndiceUVB_.csv', 'data\\360042_XXXX_IndiceUVB_.csv', 'data\\370033_XXXX_IndiceUVB_.csv', 'data\\380029_XXXX_IndiceUVB_.csv', 'data\\410005_XXXX_IndiceUVB_.csv', 'data\\450004_XXXX_IndiceUVB_.csv', 'data\\520006_XXXX_IndiceUVB_.csv', 'data\\950001_XXXX_IndiceUVB_.csv']
# ----------------------------------------

# %% [markdown]
# ## Limpieza de datos recibidos

# %%
"""
NOTAS

Tras una inspección visual de los archivos csv resultantes de la descarga:

- Se pudieron identificar varios archivos sin headers, sin la primera fila que tiene sus nombres de columnas
- Se pudo verificar que en todos los archivos la primera fila de headers, estaba separada por , mientras el resto
  del archivo quedó con ; como separador

"""

# %% [markdown]
# ### Limpieza 1

# %%
# Limpieza 1: Para solucionar fila de headers separa por , en vez de ;
# Nota: Funciona bien gracias a que el separador de decimales es . por lo que no interfiere en caso de que no haya fila de headers

# Función para modificar la primera línea de un archivo y reemplazar , por ;
def modificar_primera_linea(archivo):
    """
    Args
        archivo (path): ruta a uno de los archivos csv
    """
    with open(archivo, 'r') as file:
        lineas = file.readlines()
    
    # Modificar la primera línea reemplazando ',' por ';'
    lineas[0] = lineas[0].replace(',', ';')
    
    with open(archivo, 'w') as file:
        file.writelines(lineas)

# APLICACIÓN EN BUCLE #
for concepto, archivos in archivos_por_concepto.items():
    for archivo in archivos:
        modificar_primera_linea(archivo)

# %% [markdown]
# ## Limpieza 2

# %%
# EXPLORACION PREVIA #

# Función para verificar la estructura de los archivos de un concepto
def verificar_estructura_concepto(archivos):
    """
    Args
        archivos (lista): Lista de archivos de uno de los conceptos
    """
    estructuras = []

    for archivo in archivos:
        # Cargar el archivo CSV como DataFrame
        df = pd.read_csv(archivo, delimiter=";")
        # Obtener las columnas y tipos de datos
        estructura = {
            'columnas': df.columns.tolist(),
            'tipos_datos': df.dtypes.to_dict()
        }
        # Agregar la estructura a la lista
        estructuras.append(estructura)
    
    # Comparar todas las estructuras con la primera
    primera_estructura = estructuras[0]

    print("Estructura: ", primera_estructura)

    flag_error = 0
    for i, estructura in enumerate(estructuras[1:]):
        if estructura['columnas'] != primera_estructura['columnas']:
            print(f"El archivo {archivos[i+1]} tiene columnas diferentes.")
            print(estructura['columnas'])
            flag_error = 1
        if estructura['tipos_datos'] != primera_estructura['tipos_datos']:
            print(f"El archivo {archivos[i+1]} tiene tipos de datos diferentes.")
            flag_error = 1
    
    return flag_error

# Verificar la estructura para cada concepto
for concepto, archivos in archivos_por_concepto.items():
    if archivos:  # Solo verificar si hay archivos para el concepto
        print(f"Verificando concepto: {concepto}")
        flag_error = verificar_estructura_concepto(archivos)
        if flag_error == 0:
            print(f"Todos los archivos del concepto '{concepto}' tienen la misma estructura.")
        else:
            print(f"¡Advertencia! Los archivos del concepto '{concepto}' no tienen la misma estructura.")
        print("-" * 60)
# Out:
# Verificando concepto: DiarioTs
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'MediaCli_Valor', 'MediaAri_Valor', 'NumDatos_Valor', 'Ts00_Valor', 'Ts12_Valor', 'Maxima_Valor', 'FechaMax_Valor', 'Minima_Valor', 'FechaMin_Valor', 'FechaPro_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'MediaCli_Valor': dtype('float64'), 'MediaAri_Valor': dtype('float64'), 'NumDatos_Valor': dtype('float64'), 'Ts00_Valor': dtype('float64'), 'Ts12_Valor': dtype('float64'), 'Maxima_Valor': dtype('float64'), 'FechaMax_Valor': dtype('float64'), 'Minima_Valor': dtype('float64'), 'FechaMin_Valor': dtype('float64'), 'FechaPro_Valor': dtype('float64')}}
# Todos los archivos del concepto 'DiarioTs' tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: Humedad
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'HR_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'HR_Valor': dtype('float64')}}
# El archivo data\390006_XXXX_Humedad_.csv tiene columnas diferentes.
# ['390006', '01-01-1969 00:00:00', '69.0']
# El archivo data\390006_XXXX_Humedad_.csv tiene tipos de datos diferentes.
# El archivo data\430004_XXXX_Humedad_.csv tiene columnas diferentes.
# ['430004', '01-01-1955 00:00:00', 'Unnamed: 2']
# El archivo data\430004_XXXX_Humedad_.csv tiene tipos de datos diferentes.
# El archivo data\950001_XXXX_Humedad_.csv tiene columnas diferentes.
# ['950001', '01-01-1972 00:00:00', '82.0']
# El archivo data\950001_XXXX_Humedad_.csv tiene tipos de datos diferentes.
# ¡Advertencia! Los archivos del concepto 'Humedad' no tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: PresionQFF
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'QFF_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'QFF_Valor': dtype('float64')}}
# El archivo data\220002_XXXX_PresionQFF_.csv tiene columnas diferentes.
# ['220002', '01-01-1990 00:00:00', 'Unnamed: 2']
# El archivo data\220002_XXXX_PresionQFF_.csv tiene tipos de datos diferentes.
# El archivo data\390006_XXXX_PresionQFF_.csv tiene columnas diferentes.
# ['390006', '01-01-1969 00:00:00', 'Unnamed: 2']
# El archivo data\390006_XXXX_PresionQFF_.csv tiene tipos de datos diferentes.
# El archivo data\430004_XXXX_PresionQFF_.csv tiene columnas diferentes.
# ['430004', '01-01-1955 00:00:00', 'Unnamed: 2']
# El archivo data\430004_XXXX_PresionQFF_.csv tiene tipos de datos diferentes.
# ¡Advertencia! Los archivos del concepto 'PresionQFF' no tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: Temperatura
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'Ts_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'Ts_Valor': dtype('float64')}}
# El archivo data\430004_XXXX_Temperatura_.csv tiene columnas diferentes.
# ['430004', '01-01-1955 00:00:00', 'Unnamed: 2']
# El archivo data\430004_XXXX_Temperatura_.csv tiene tipos de datos diferentes.
# ¡Advertencia! Los archivos del concepto 'Temperatura' no tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: Viento
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'dd_Valor', 'ff_Valor', 'VRB_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'dd_Valor': dtype('float64'), 'ff_Valor': dtype('float64'), 'VRB_Valor': dtype('float64')}}
# El archivo data\430004_XXXX_Viento_.csv tiene columnas diferentes.
# ['430004', '01-01-1955 00:00:00', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']
# El archivo data\430004_XXXX_Viento_.csv tiene tipos de datos diferentes.
# El archivo data\520006_XXXX_Viento_.csv tiene columnas diferentes.
# ['520006', '01-01-1967 00:00:00', '220.0', '20.0', '0.0']
# El archivo data\520006_XXXX_Viento_.csv tiene tipos de datos diferentes.
# ¡Advertencia! Los archivos del concepto 'Viento' no tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: Agua24Horas
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'RRR24_Valor', 'Traza_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'RRR24_Valor': dtype('float64'), 'Traza_Valor': dtype('float64')}}
# Todos los archivos del concepto 'Agua24Horas' tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: Agua6Horas
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'RRR6_Valor', 'Traza_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'RRR6_Valor': dtype('float64'), 'Traza_Valor': dtype('float64')}}
# El archivo data\450001_XXXX_Agua6Horas_.csv tiene columnas diferentes.
# ['450001', '01-01-1960 00:00:00', '0.0', '0.0.1']
# El archivo data\450001_XXXX_Agua6Horas_.csv tiene tipos de datos diferentes.
# El archivo data\510005_XXXX_Agua6Horas_.csv tiene columnas diferentes.
# ['510005', '01-01-1999 00:00:00', '0.0', '0.0.1']
# El archivo data\510005_XXXX_Agua6Horas_.csv tiene tipos de datos diferentes.
# ¡Advertencia! Los archivos del concepto 'Agua6Horas' no tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: DiarioRR
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'Total_Valor', 'Traza_Valor', 'Parcial_Valor', 'NumDatos_Valor', 'FechaPro_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'Total_Valor': dtype('float64'), 'Traza_Valor': dtype('float64'), 'Parcial_Valor': dtype('float64'), 'NumDatos_Valor': dtype('float64'), 'FechaPro_Valor': dtype('float64')}}
# Todos los archivos del concepto 'DiarioRR' tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: PresionQFE
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'QFE_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'QFE_Valor': dtype('float64')}}
# El archivo data\390006_XXXX_PresionQFE_.csv tiene columnas diferentes.
# ['390006', '01-01-1969 00:00:00', 'Unnamed: 2']
# El archivo data\390006_XXXX_PresionQFE_.csv tiene tipos de datos diferentes.
# El archivo data\460001_XXXX_PresionQFE_.csv tiene columnas diferentes.
# ['460001', '01-01-1969 00:00:00', 'Unnamed: 2']
# El archivo data\460001_XXXX_PresionQFE_.csv tiene tipos de datos diferentes.
# ¡Advertencia! Los archivos del concepto 'PresionQFE' no tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: PuntoRocio
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'Td_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'Td_Valor': dtype('float64')}}
# El archivo data\390006_XXXX_PuntoRocio_.csv tiene columnas diferentes.
# ['390006', '01-01-1969 00:00:00', '11.8']
# El archivo data\390006_XXXX_PuntoRocio_.csv tiene tipos de datos diferentes.
# ¡Advertencia! Los archivos del concepto 'PuntoRocio' no tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: TMaxima
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'TxPM_Valor', 'FechaHora_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'TxPM_Valor': dtype('float64'), 'FechaHora_Valor': dtype('O')}}
# El archivo data\430004_XXXX_TMaxima_.csv tiene columnas diferentes.
# ['430004', '01-01-1955 00:00:00', 'Unnamed: 2', '01-01-1970 00:00']
# El archivo data\430004_XXXX_TMaxima_.csv tiene tipos de datos diferentes.
# ¡Advertencia! Los archivos del concepto 'TMaxima' no tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: TMinima
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'TnAM_Valor', 'FechaHora_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'TnAM_Valor': dtype('float64'), 'FechaHora_Valor': dtype('O')}}
# Todos los archivos del concepto 'TMinima' tienen la misma estructura.
# ------------------------------------------------------------
# Verificando concepto: IndiceUVB
# Estructura:  {'columnas': ['CodigoNacional', 'momento', 'IUV_Valor'], 'tipos_datos': {'CodigoNacional': dtype('int64'), 'momento': dtype('O'), 'IUV_Valor': dtype('float64')}}
# Todos los archivos del concepto 'IndiceUVB' tienen la misma estructura.
# ------------------------------------------------------------

# %%
# Preparación de Limpieza: Agregado de características flag

# El algoritmo de limpieza solo debe ser aplicado a los archivos donde es necesario, para ello primero deben ser identificados con una flag

# Generación de diccionario temporal con flags #

archivos_por_concepto_flag = archivos_por_concepto.copy()

for concepto, archivos in archivos_por_concepto.items():
    archivos_por_concepto_flag[concepto] = [{archivo: {"estructura": 0, "tipos":0}} for archivo in archivos]

# Diccionario para enlistar los archivos csv por concepto agregndo características flag estructura y tipo a cada uno
# {
#  concepto1:[
#   {csv1:{
#       estructura:0;
#       tipos:0
#       }
#   },
#   {csv2:{
#       estructura:0;
#       tipos:0
#       }
#   }
#  ]; 
#  concepto2:[
#   {csv1:{
#       estructura:0;
#       tipos:0
#       }
#   },
#   {csv2:{
#       estructura:0;
#       tipos:0
#       }
#   }
#  ];...
# }


# Verificar la estructura para cada concepto
for concepto, archivos in archivos_por_concepto_flag.items():
    if archivos:  # Solo verificar si hay archivos para el concepto

        print(f"Verificando concepto: {concepto}")

        # Cargar la estructura del primer archivo

        # Nota: Se está asumiendo que el primer archivo tendrá la columna de headers.

        # Nota de desarrollo: Se podría agregar una comprobación de que la primera clave de la primera fila en análisis sea "CodigoNacional", 
        # y sino, pasar al siguiente archivo y vovler a hcer la comprobación para usar de modelo

        primer_archivo = list(archivos[0].keys())[0]
        df_primer = pd.read_csv(primer_archivo, delimiter=";") # Nota: Esto lee todo el archivo, se puede optimizar para leer solo lo primero

        primera_estructura = {
            'columnas': df_primer.columns.tolist(),
            'tipos_datos': df_primer.dtypes.to_dict()
        }

        print("Estructura de referencia: ", primera_estructura)

        # Para cada archivo con sus características
        for dicc in archivos[1:]:
            # Bucle sobre variables/ubicación para modificar en diccionario
            for archivo, dic_atrib in dicc.items():
                
                # Apertura de archivo 
                df = pd.read_csv(archivo, delimiter=";") # Nota: Esto lee todo el archivo, se puede optimizar para leer solo lo primero

                estructura_actual = {
                    'columnas': df.columns.tolist(),
                    'tipos_datos': df.dtypes.to_dict()
                }

                if estructura_actual['columnas'] != primera_estructura['columnas']:
                    print(f"El archivo {archivo} tiene columnas diferentes.")
                    dic_atrib['estructura'] = 1 # Seteo de flag

                if estructura_actual['tipos_datos'] != primera_estructura['tipos_datos']:
                    print(f"El archivo {archivo} tiene tipos de datos diferentes.")
                    dic_atrib['tipos'] = 1 # Seteo de flag
# Out:
# {'DiarioTs': [{'data\\180005_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\200006_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\220002_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\230001_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\270001_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\270008_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\290004_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\320041_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\320051_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330007_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330019_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330020_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330021_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330030_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330031_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330066_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330077_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330111_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330112_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330113_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\340031_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\360011_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\360019_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\360042_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\370033_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\380029_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\390006_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\400009_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\410005_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\420014_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\430002_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\430004_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\430009_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\450001_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\450004_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\450005_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\460001_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\470001_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\510005_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\520006_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\530005_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\550001_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\950001_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\950002_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\950003_XXXX_DiarioTs_.csv': {'estructura': 0, 'tipos': 0}}], 'Humedad': [{'data\\180005_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\200006_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\220002_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\230001_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\270001_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\270008_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\290004_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\320041_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\320051_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330007_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330019_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330020_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330021_XXXX_Humedad_.csv': {'estructura': 0, 'tipos': 0}}, {'data\\330030_XXXX_Humedad_.csv': {'estru ...

# %% [markdown]
# ## Consolidación de archivos

# %%
# Lectura de archivos :

# Abrir los archivos con una opción
    # Condición 0: Se abre con sus header
    # Confición 1: Se abre con los header del primer archivo

# Esto continua asumiendo que el primer archivo tiene sus headers bien.

for concepto, archivos in archivos_por_concepto_flag.items():
    if archivos:  # Solo verificar si hay archivos para el concepto

        print(f"Unificando CSVs: {concepto}")

        # Cargar la estructura del primer archivo
        primer_archivo = list(archivos[0].keys())[0]
        df_primer = pd.read_csv(primer_archivo, delimiter=";")
        columnas_csv = df_primer.columns.tolist()

        print(columnas_csv)

        # lista de dfs para concatenar
        dfs = [df_primer]

        for dicc in archivos[1:]:
            for archivo, dic_atrib in dicc.items():
                if dic_atrib['estructura'] == 0:
                    print(f"{archivo} → Estructura bien")
                    df_temp = pd.read_csv(archivo, delimiter=";")
                elif dic_atrib['estructura'] == 1:
                    print(f"{archivo} → Estructura mal")
                    df_temp = pd.read_csv(archivo, delimiter=";", header=None, names=columnas_csv)
                
                dfs.append(df_temp)

        # Concatenar todos los DataFrames
        df_final = pd.concat(dfs, ignore_index=True)

        # Guardar el DataFrame consolidado
        ruta_salida = f"data/{concepto}_consolidado.csv"
        df_final.to_csv(ruta_salida, index=False, sep=";")
        print(f"Archivo consolidado guardado en: {ruta_salida}")
# Out:
# Unificando CSVs: DiarioTs
# ['CodigoNacional', 'momento', 'MediaCli_Valor', 'MediaAri_Valor', 'NumDatos_Valor', 'Ts00_Valor', 'Ts12_Valor', 'Maxima_Valor', 'FechaMax_Valor', 'Minima_Valor', 'FechaMin_Valor', 'FechaPro_Valor']
# data\200006_XXXX_DiarioTs_.csv → Estructura bien
# data\220002_XXXX_DiarioTs_.csv → Estructura bien
# data\230001_XXXX_DiarioTs_.csv → Estructura bien
# data\270001_XXXX_DiarioTs_.csv → Estructura bien
# data\270008_XXXX_DiarioTs_.csv → Estructura bien
# data\290004_XXXX_DiarioTs_.csv → Estructura bien
# data\320041_XXXX_DiarioTs_.csv → Estructura bien
# data\320051_XXXX_DiarioTs_.csv → Estructura bien
# data\330007_XXXX_DiarioTs_.csv → Estructura bien
# data\330019_XXXX_DiarioTs_.csv → Estructura bien
# data\330020_XXXX_DiarioTs_.csv → Estructura bien
# data\330021_XXXX_DiarioTs_.csv → Estructura bien
# data\330030_XXXX_DiarioTs_.csv → Estructura bien
# data\330031_XXXX_DiarioTs_.csv → Estructura bien
# data\330066_XXXX_DiarioTs_.csv → Estructura bien
# data\330077_XXXX_DiarioTs_.csv → Estructura bien
# data\330111_XXXX_DiarioTs_.csv → Estructura bien
# data\330112_XXXX_DiarioTs_.csv → Estructura bien
# data\330113_XXXX_DiarioTs_.csv → Estructura bien
# data\340031_XXXX_DiarioTs_.csv → Estructura bien
# data\360011_XXXX_DiarioTs_.csv → Estructura bien
# data\360019_XXXX_DiarioTs_.csv → Estructura bien
# data\360042_XXXX_DiarioTs_.csv → Estructura bien
# data\370033_XXXX_DiarioTs_.csv → Estructura bien
# data\380029_XXXX_DiarioTs_.csv → Estructura bien
# data\390006_XXXX_DiarioTs_.csv → Estructura bien
# data\400009_XXXX_DiarioTs_.csv → Estructura bien
# data\410005_XXXX_DiarioTs_.csv → Estructura bien
# data\420014_XXXX_DiarioTs_.csv → Estructura bien
# data\430002_XXXX_DiarioTs_.csv → Estructura bien
# data\430004_XXXX_DiarioTs_.csv → Estructura bien
# data\430009_XXXX_DiarioTs_.csv → Estructura bien
# data\450001_XXXX_DiarioTs_.csv → Estructura bien
# data\450004_XXXX_DiarioTs_.csv → Estructura bien
# data\450005_XXXX_DiarioTs_.csv → Estructura bien
# data\460001_XXXX_DiarioTs_.csv → Estructura bien
# data\470001_XXXX_DiarioTs_.csv → Estructura bien
# data\510005_XXXX_DiarioTs_.csv → Estructura bien
# data\520006_XXXX_DiarioTs_.csv → Estructura bien
# data\530005_XXXX_DiarioTs_.csv → Estructura bien
# data\550001_XXXX_DiarioTs_.csv → Estructura bien
# data\950001_XXXX_DiarioTs_.csv → Estructura bien
# data\950002_XXXX_DiarioTs_.csv → Estructura bien
# data\950003_XXXX_DiarioTs_.csv → Estructura bien
# Archivo consolidado guardado en: data/DiarioTs_consolidado.csv
# Unificando CSVs: Humedad
# ['CodigoNacional', 'momento', 'HR_Valor']
# data\200006_XXXX_Humedad_.csv → Estructura bien
# data\220002_XXXX_Humedad_.csv → Estructura bien
# data\230001_XXXX_Humedad_.csv → Estructura bien
# data\270001_XXXX_Humedad_.csv → Estructura bien
# data\270008_XXXX_Humedad_.csv → Estructura bien
# data\290004_XXXX_Humedad_.csv → Estructura bien
# data\320041_XXXX_Humedad_.csv → Estructura bien
# data\320051_XXXX_Humedad_.csv → Estructura bien
# data\330007_XXXX_Humedad_.csv → Estructura bien
# data\330019_XXXX_Humedad_.csv → Estructura bien
# data\330020_XXXX_Humedad_.csv → Estructura bien
# data\330021_XXXX_Humedad_.csv → Estructura bien
# data\330030_XXXX_Humedad_.csv → Estructura bien
# data\330031_XXXX_Humedad_.csv → Estructura bien
# data\330066_XXXX_Humedad_.csv → Estructura bien
# data\330077_XXXX_Humedad_.csv → Estructura bien
# data\330111_XXXX_Humedad_.csv → Estructura bien
# data\330112_XXXX_Humedad_.csv → Estructura bien
# data\330113_XXXX_Humedad_.csv → Estructura bien
# data\340031_XXXX_Humedad_.csv → Estructura bien
# data\360011_XXXX_Humedad_.csv → Estructura bien
# data\360019_XXXX_Humedad_.csv → Estructura bien
# data\360042_XXXX_Humedad_.csv → Estructura bien
# data\370033_XXXX_Humedad_.csv → Estructura bien
# data\380029_XXXX_Humedad_.csv → Estructura bien
# data\390006_XXXX_Humedad_.csv → Estructura mal
# data\400009_XXXX_Humedad_.csv → Estructura bien
# data\410005_XXXX_Humedad_.csv → Estructura bien
# data\420014_XXXX_Humedad_.csv → Estructura bien
# data\430002_XXXX_Humedad_.csv → Estructura bien
# data\430004_XXXX_Humedad_.csv → Estructura mal
# data\430009_XXXX_Humedad_.csv → Estructura bien
# data\450001_XXXX_Humedad_.csv → Estructura bien
# data\450004_XXXX_Humedad_.csv → Estructura bien
# data\450005_XXXX_Humedad_.csv → Estructura bien
# data\460001_XXXX_Humedad_.csv → Estructura bien
# data\470001_XXXX_Humedad_.csv → Estructura bien
# data\510005_XXXX_Humedad_.csv → Estructura bien
# data\520006_XXXX_Humedad_.csv → Estructura bien
# data\530005_XXXX_Humedad_.csv → Estructura bien
# data\550001_XXXX_Humedad_.csv → Estructura bien
# data\950001_XXXX_Humedad_.csv → Estructura mal
# data\950002_XXXX_Humedad_.csv → Estructura bien
# data\950003_XXXX_Humedad_.csv → Estructura bien
# Archivo consolidado guardado en: data/Humedad_consolidado.csv
# Unificando CSVs: PresionQFF
# ['CodigoNacional', 'momento', 'QFF_Valor']
# data\200006_XXXX_PresionQFF_.csv → Estructura bien
# data\220002_XXXX_PresionQFF_.csv → Estructura mal
# data\230001_XXXX_PresionQFF_.csv → Estructura bien
# data\270001_XXXX_PresionQFF_.csv → Estructura bien
# data\270008_XXXX_PresionQFF_.csv → Estructura bien
# data\290004_XXXX_PresionQFF_.csv → Estructura bien
# data\320041_XXXX_PresionQFF_.csv → Estructura bien
# data\320051_XXXX_PresionQFF_.csv → Estructura bien
# data\330007_XXXX_PresionQFF_.csv → Estructura bien
# data\330019_XXXX_PresionQFF_.csv → Estructura bien
# data\330020_XXXX_PresionQFF_.csv → Estructura bien
# data\330021_XXXX_PresionQFF_.csv → Estructura bien
# data\330030_XXXX_PresionQFF_.csv → Estructura bien
# data\330031_XXXX_PresionQFF_.csv → Estructura bien
# data\330066_XXXX_PresionQFF_.csv → Estructura bien
# data\330077_XXXX_PresionQFF_.csv → Estructura bien
# data\330111_XXXX_PresionQFF_.csv → Estructura bien
# data\330112_XXXX_PresionQFF_.csv → Estructura bien
# data\330113_XXXX_PresionQFF_.csv → Estructura bien
# data\340031_XXXX_PresionQFF_.csv → Estructura bien
# data\360011_XXXX_PresionQFF_.csv → Estructura bien
# data\360019_XXXX_PresionQFF_.csv → Estructura bien
# data\360042_XXXX_PresionQFF_.csv → Estructura bien
# data\370033_XXXX_PresionQFF_.csv → Estructura bien
# data\380029_XXXX_PresionQFF_.csv → Estructura bien
# data\390006_XXXX_PresionQFF_.csv → Estructura mal
# data\400009_XXXX_PresionQFF_.csv → Estructura bien
# data\410005_XXXX_PresionQFF_.csv → Estructura bien
# data\420014_XXXX_PresionQFF_.csv → Estructura bien
# data\430002_XXXX_PresionQFF_.csv → Estructura bien
# data\430004_XXXX_PresionQFF_.csv → Estructura mal
# data\430009_XXXX_PresionQFF_.csv → Estructura bien
# data\450001_XXXX_PresionQFF_.csv → Estructura bien
# data\450004_XXXX_PresionQFF_.csv → Estructura bien
# data\450005_XXXX_PresionQFF_.csv → Estructura bien
# data\460001_XXXX_PresionQFF_.csv → Estructura bien
# data\470001_XXXX_PresionQFF_.csv → Estructura bien
# data\510005_XXXX_PresionQFF_.csv → Estructura bien
# data\520006_XXXX_PresionQFF_.csv → Estructura bien
# data\530005_XXXX_PresionQFF_.csv → Estructura bien
# data\550001_XXXX_PresionQFF_.csv → Estructura bien
# data\950001_XXXX_PresionQFF_.csv → Estructura bien
# data\950002_XXXX_PresionQFF_.csv → Estructura bien
# data\950003_XXXX_PresionQFF_.csv → Estructura bien
# Archivo consolidado guardado en: data/PresionQFF_consolidado.csv
# Unificando CSVs: Temperatura
# ['CodigoNacional', 'momento', 'Ts_Valor']
# data\200006_XXXX_Temperatura_.csv → Estructura bien
# data\220002_XXXX_Temperatura_.csv → Estructura bien
# data\230001_XXXX_Temperatura_.csv → Estructura bien
# data\270001_XXXX_Temperatura_.csv → Estructura bien
# data\270008_XXXX_Temperatura_.csv → Estructura bien
# data\290004_XXXX_Temperatura_.csv → Estructura bien
# data\320041_XXXX_Temperatura_.csv → Estructura bien
# data\320051_XXXX_Temperatura_.csv → Estructura bien
# data\330007_XXXX_Temperatura_.csv → Estructura bien
# data\330019_XXXX_Temperatura_.csv → Estructura bien
# data\330020_XXXX_Temperatura_.csv → Estructura bien
# data\330021_XXXX_Temperatura_.csv → Estructura bien
# data\330030_XXXX_Temperatura_.csv → Estructura bien
# data\330031_XXXX_Temperatura_.csv → Estructura bien
# data\330066_XXXX_Temperatura_.csv → Estructura bien
# data\330077_XXXX_Temperatura_.csv → Estructura bien
# data\330111_XXXX_Temperatura_.csv → Estructura bien
# data\330112_XXXX_Temperatura_.csv → Estructura bien
# data\330113_XXXX_Temperatura_.csv → Estructura bien
# data\340031_XXXX_Temperatura_.csv → Estructura bien
# data\360011_XXXX_Temperatura_.csv → Estructura bien
# data\360019_XXXX_Temperatura_.csv → Estructura bien
# data\360042_XXXX_Temperatura_.csv → Estructura bien
# data\370033_XXXX_Temperatura_.csv → Estructura bien
# data\380029_XXXX_Temperatura_.csv → Estructura bien
# data\390006_XXXX_Temperatura_.csv → Estructura bien
# data\400009_XXXX_Temperatura_.csv → Estructura bien
# data\410005_XXXX_Temperatura_.csv → Estructura bien
# data\420014_XXXX_Temperatura_.csv → Estructura bien
# data\430002_XXXX_Temperatura_.csv → Estructura bien
# data\430004_XXXX_Temperatura_.csv → Estructura mal
# data\430009_XXXX_Temperatura_.csv → Estructura bien
# data\450001_XXXX_Temperatura_.csv → Estructura bien
# data\450004_XXXX_Temperatura_.csv → Estructura bien
# data\450005_XXXX_Temperatura_.csv → Estructura bien
# data\460001_XXXX_Temperatura_.csv → Estructura bien
# data\470001_XXXX_Temperatura_.csv → Estructura bien
# data\510005_XXXX_Temperatura_.csv → Estructura bien
# data\520006_XXXX_Temperatura_.csv → Estructura bien
# data\530005_XXXX_Temperatura_.csv → Estructura bien
# data\550001_XXXX_Temperatura_.csv → Estructura bien
# data\950001_XXXX_Temperatura_.csv → Estructura bien
# data\950002_XXXX_Temperatura_.csv → Estructura bien
# data\950003_XXXX_Temperatura_.csv → Estructura bien
# Archivo consolidado guardado en: data/Temperatura_consolidado.csv
# Unificando CSVs: Viento
# ['CodigoNacional', 'momento', 'dd_Valor', 'ff_Valor', 'VRB_Valor']
# data\200006_XXXX_Viento_.csv → Estructura bien
# data\220002_XXXX_Viento_.csv → Estructura bien
# data\230001_XXXX_Viento_.csv → Estructura bien
# data\270001_XXXX_Viento_.csv → Estructura bien
# data\270008_XXXX_Viento_.csv → Estructura bien
# data\290004_XXXX_Viento_.csv → Estructura bien
# data\320041_XXXX_Viento_.csv → Estructura bien
# data\320051_XXXX_Viento_.csv → Estructura bien
# data\330007_XXXX_Viento_.csv → Estructura bien
# data\330019_XXXX_Viento_.csv → Estructura bien
# data\330020_XXXX_Viento_.csv → Estructura bien
# data\330021_XXXX_Viento_.csv → Estructura bien
# data\330030_XXXX_Viento_.csv → Estructura bien
# data\330031_XXXX_Viento_.csv → Estructura bien
# data\330066_XXXX_Viento_.csv → Estructura bien
# data\330077_XXXX_Viento_.csv → Estructura bien
# data\330111_XXXX_Viento_.csv → Estructura bien
# data\330112_XXXX_Viento_.csv → Estructura bien
# data\330113_XXXX_Viento_.csv → Estructura bien
# data\340031_XXXX_Viento_.csv → Estructura bien
# data\360011_XXXX_Viento_.csv → Estructura bien
# data\360019_XXXX_Viento_.csv → Estructura bien
# data\360042_XXXX_Viento_.csv → Estructura bien
# data\370033_XXXX_Viento_.csv → Estructura bien
# data\380029_XXXX_Viento_.csv → Estructura bien
# data\390006_XXXX_Viento_.csv → Estructura bien
# data\400009_XXXX_Viento_.csv → Estructura bien
# data\410005_XXXX_Viento_.csv → Estructura bien
# data\420014_XXXX_Viento_.csv → Estructura bien
# data\430002_XXXX_Viento_.csv → Estructura bien
# data\430004_XXXX_Viento_.csv → Estructura mal
# data\430009_XXXX_Viento_.csv → Estructura bien
# data\450001_XXXX_Viento_.csv → Estructura bien
# data\450004_XXXX_Viento_.csv → Estructura bien
# data\450005_XXXX_Viento_.csv → Estructura bien
# data\460001_XXXX_Viento_.csv → Estructura bien
# data\470001_XXXX_Viento_.csv → Estructura bien
# data\510005_XXXX_Viento_.csv → Estructura bien
# data\520006_XXXX_Viento_.csv → Estructura mal
# data\530005_XXXX_Viento_.csv → Estructura bien
# data\550001_XXXX_Viento_.csv → Estructura bien
# data\950001_XXXX_Viento_.csv → Estructura bien
# data\950002_XXXX_Viento_.csv → Estructura bien
# data\950003_XXXX_Viento_.csv → Estructura bien
# Archivo consolidado guardado en: data/Viento_consolidado.csv
# Unificando CSVs: Agua24Horas
# ['CodigoNacional', 'momento', 'RRR24_Valor', 'Traza_Valor']
# data\200006_XXXX_Agua24Horas_.csv → Estructura bien
# data\220002_XXXX_Agua24Horas_.csv → Estructura bien
# data\230001_XXXX_Agua24Horas_.csv → Estructura bien
# data\270008_XXXX_Agua24Horas_.csv → Estructura bien
# data\290004_XXXX_Agua24Horas_.csv → Estructura bien
# data\320041_XXXX_Agua24Horas_.csv → Estructura bien
# data\330007_XXXX_Agua24Horas_.csv → Estructura bien
# data\330019_XXXX_Agua24Horas_.csv → Estructura bien
# data\330020_XXXX_Agua24Horas_.csv → Estructura bien
# data\330021_XXXX_Agua24Horas_.csv → Estructura bien
# data\330030_XXXX_Agua24Horas_.csv → Estructura bien
# data\330031_XXXX_Agua24Horas_.csv → Estructura bien
# data\330066_XXXX_Agua24Horas_.csv → Estructura bien
# data\340031_XXXX_Agua24Horas_.csv → Estructura bien
# data\360011_XXXX_Agua24Horas_.csv → Estructura bien
# data\360019_XXXX_Agua24Horas_.csv → Estructura bien
# data\360042_XXXX_Agua24Horas_.csv → Estructura bien
# data\370033_XXXX_Agua24Horas_.csv → Estructura bien
# data\380029_XXXX_Agua24Horas_.csv → Estructura bien
# data\390006_XXXX_Agua24Horas_.csv → Estructura bien
# data\400009_XXXX_Agua24Horas_.csv → Estructura bien
# data\410005_XXXX_Agua24Horas_.csv → Estructura bien
# data\420014_XXXX_Agua24Horas_.csv → Estructura bien
# data\430002_XXXX_Agua24Horas_.csv → Estructura bien
# data\430004_XXXX_Agua24Horas_.csv → Estructura bien
# data\450001_XXXX_Agua24Horas_.csv → Estructura bien
# data\450004_XXXX_Agua24Horas_.csv → Estructura bien
# data\450005_XXXX_Agua24Horas_.csv → Estructura bien
# data\460001_XXXX_Agua24Horas_.csv → Estructura bien
# data\470001_XXXX_Agua24Horas_.csv → Estructura bien
# data\510005_XXXX_Agua24Horas_.csv → Estructura bien
# data\520006_XXXX_Agua24Horas_.csv → Estructura bien
# data\530005_XXXX_Agua24Horas_.csv → Estructura bien
# data\550001_XXXX_Agua24Horas_.csv → Estructura bien
# data\950001_XXXX_Agua24Horas_.csv → Estructura bien
# data\950002_XXXX_Agua24Horas_.csv → Estructura bien
# data\950003_XXXX_Agua24Horas_.csv → Estructura bien
# Archivo consolidado guardado en: data/Agua24Horas_consolidado.csv
# Unificando CSVs: Agua6Horas
# ['CodigoNacional', 'momento', 'RRR6_Valor', 'Traza_Valor']
# data\200006_XXXX_Agua6Horas_.csv → Estructura bien
# data\220002_XXXX_Agua6Horas_.csv → Estructura bien
# data\230001_XXXX_Agua6Horas_.csv → Estructura bien
# data\270001_XXXX_Agua6Horas_.csv → Estructura bien
# data\270008_XXXX_Agua6Horas_.csv → Estructura bien
# data\290004_XXXX_Agua6Horas_.csv → Estructura bien
# data\320041_XXXX_Agua6Horas_.csv → Estructura bien
# data\320051_XXXX_Agua6Horas_.csv → Estructura bien
# data\330007_XXXX_Agua6Horas_.csv → Estructura bien
# data\330019_XXXX_Agua6Horas_.csv → Estructura bien
# data\330020_XXXX_Agua6Horas_.csv → Estructura bien
# data\330021_XXXX_Agua6Horas_.csv → Estructura bien
# data\330030_XXXX_Agua6Horas_.csv → Estructura bien
# data\330031_XXXX_Agua6Horas_.csv → Estructura bien
# data\330066_XXXX_Agua6Horas_.csv → Estructura bien
# data\330077_XXXX_Agua6Horas_.csv → Estructura bien
# data\330111_XXXX_Agua6Horas_.csv → Estructura bien
# data\330112_XXXX_Agua6Horas_.csv → Estructura bien
# data\330113_XXXX_Agua6Horas_.csv → Estructura bien
# data\340031_XXXX_Agua6Horas_.csv → Estructura bien
# data\360011_XXXX_Agua6Horas_.csv → Estructura bien
# data\360019_XXXX_Agua6Horas_.csv → Estructura bien
# data\360042_XXXX_Agua6Horas_.csv → Estructura bien
# data\370033_XXXX_Agua6Horas_.csv → Estructura bien
# data\380029_XXXX_Agua6Horas_.csv → Estructura bien
# data\390006_XXXX_Agua6Horas_.csv → Estructura bien
# data\400009_XXXX_Agua6Horas_.csv → Estructura bien
# data\410005_XXXX_Agua6Horas_.csv → Estructura bien
# data\420014_XXXX_Agua6Horas_.csv → Estructura bien
# data\430002_XXXX_Agua6Horas_.csv → Estructura bien
# data\430004_XXXX_Agua6Horas_.csv → Estructura bien
# data\430009_XXXX_Agua6Horas_.csv → Estructura bien
# data\450001_XXXX_Agua6Horas_.csv → Estructura mal
# data\450004_XXXX_Agua6Horas_.csv → Estructura bien
# data\450005_XXXX_Agua6Horas_.csv → Estructura bien
# data\460001_XXXX_Agua6Horas_.csv → Estructura bien
# data\470001_XXXX_Agua6Horas_.csv → Estructura bien
# data\510005_XXXX_Agua6Horas_.csv → Estructura mal
# data\520006_XXXX_Agua6Horas_.csv → Estructura bien
# data\530005_XXXX_Agua6Horas_.csv → Estructura bien
# data\550001_XXXX_Agua6Horas_.csv → Estructura bien
# data\950001_XXXX_Agua6Horas_.csv → Estructura bien
# data\950002_XXXX_Agua6Horas_.csv → Estructura bien
# data\950003_XXXX_Agua6Horas_.csv → Estructura bien
# Archivo consolidado guardado en: data/Agua6Horas_consolidado.csv
# Unificando CSVs: DiarioRR
# ['CodigoNacional', 'momento', 'Total_Valor', 'Traza_Valor', 'Parcial_Valor', 'NumDatos_Valor', 'FechaPro_Valor']
# data\200006_XXXX_DiarioRR_.csv → Estructura bien
# data\220002_XXXX_DiarioRR_.csv → Estructura bien
# data\230001_XXXX_DiarioRR_.csv → Estructura bien
# data\270001_XXXX_DiarioRR_.csv → Estructura bien
# data\270008_XXXX_DiarioRR_.csv → Estructura bien
# data\290004_XXXX_DiarioRR_.csv → Estructura bien
# data\320041_XXXX_DiarioRR_.csv → Estructura bien
# data\320051_XXXX_DiarioRR_.csv → Estructura bien
# data\330007_XXXX_DiarioRR_.csv → Estructura bien
# data\330019_XXXX_DiarioRR_.csv → Estructura bien
# data\330020_XXXX_DiarioRR_.csv → Estructura bien
# data\330021_XXXX_DiarioRR_.csv → Estructura bien
# data\330030_XXXX_DiarioRR_.csv → Estructura bien
# data\330031_XXXX_DiarioRR_.csv → Estructura bien
# data\330066_XXXX_DiarioRR_.csv → Estructura bien
# data\330077_XXXX_DiarioRR_.csv → Estructura bien
# data\330111_XXXX_DiarioRR_.csv → Estructura bien
# data\330112_XXXX_DiarioRR_.csv → Estructura bien
# data\330113_XXXX_DiarioRR_.csv → Estructura bien
# data\340031_XXXX_DiarioRR_.csv → Estructura bien
# data\360011_XXXX_DiarioRR_.csv → Estructura bien
# data\360019_XXXX_DiarioRR_.csv → Estructura bien
# data\360042_XXXX_DiarioRR_.csv → Estructura bien
# data\370033_XXXX_DiarioRR_.csv → Estructura bien
# data\380029_XXXX_DiarioRR_.csv → Estructura bien
# data\390006_XXXX_DiarioRR_.csv → Estructura bien
# data\400009_XXXX_DiarioRR_.csv → Estructura bien
# data\410005_XXXX_DiarioRR_.csv → Estructura bien
# data\420014_XXXX_DiarioRR_.csv → Estructura bien
# data\430002_XXXX_DiarioRR_.csv → Estructura bien
# data\430004_XXXX_DiarioRR_.csv → Estructura bien
# data\430009_XXXX_DiarioRR_.csv → Estructura bien
# data\450001_XXXX_DiarioRR_.csv → Estructura bien
# data\450004_XXXX_DiarioRR_.csv → Estructura bien
# data\450005_XXXX_DiarioRR_.csv → Estructura bien
# data\460001_XXXX_DiarioRR_.csv → Estructura bien
# data\470001_XXXX_DiarioRR_.csv → Estructura bien
# data\510005_XXXX_DiarioRR_.csv → Estructura bien
# data\520006_XXXX_DiarioRR_.csv → Estructura bien
# data\530005_XXXX_DiarioRR_.csv → Estructura bien
# data\550001_XXXX_DiarioRR_.csv → Estructura bien
# data\950001_XXXX_DiarioRR_.csv → Estructura bien
# data\950002_XXXX_DiarioRR_.csv → Estructura bien
# data\950003_XXXX_DiarioRR_.csv → Estructura bien
# Archivo consolidado guardado en: data/DiarioRR_consolidado.csv
# Unificando CSVs: PresionQFE
# ['CodigoNacional', 'momento', 'QFE_Valor']
# data\200006_XXXX_PresionQFE_.csv → Estructura bien
# data\220002_XXXX_PresionQFE_.csv → Estructura bien
# data\230001_XXXX_PresionQFE_.csv → Estructura bien
# data\270001_XXXX_PresionQFE_.csv → Estructura bien
# data\270008_XXXX_PresionQFE_.csv → Estructura bien
# data\290004_XXXX_PresionQFE_.csv → Estructura bien
# data\320041_XXXX_PresionQFE_.csv → Estructura bien
# data\320051_XXXX_PresionQFE_.csv → Estructura bien
# data\330007_XXXX_PresionQFE_.csv → Estructura bien
# data\330019_XXXX_PresionQFE_.csv → Estructura bien
# data\330020_XXXX_PresionQFE_.csv → Estructura bien
# data\330021_XXXX_PresionQFE_.csv → Estructura bien
# data\330030_XXXX_PresionQFE_.csv → Estructura bien
# data\330031_XXXX_PresionQFE_.csv → Estructura bien
# data\330066_XXXX_PresionQFE_.csv → Estructura bien
# data\330077_XXXX_PresionQFE_.csv → Estructura bien
# data\330111_XXXX_PresionQFE_.csv → Estructura bien
# data\330112_XXXX_PresionQFE_.csv → Estructura bien
# data\330113_XXXX_PresionQFE_.csv → Estructura bien
# data\340031_XXXX_PresionQFE_.csv → Estructura bien
# data\360011_XXXX_PresionQFE_.csv → Estructura bien
# data\360019_XXXX_PresionQFE_.csv → Estructura bien
# data\360042_XXXX_PresionQFE_.csv → Estructura bien
# data\370033_XXXX_PresionQFE_.csv → Estructura bien
# data\380029_XXXX_PresionQFE_.csv → Estructura bien
# data\390006_XXXX_PresionQFE_.csv → Estructura mal
# data\400009_XXXX_PresionQFE_.csv → Estructura bien
# data\410005_XXXX_PresionQFE_.csv → Estructura bien
# data\420014_XXXX_PresionQFE_.csv → Estructura bien
# data\430002_XXXX_PresionQFE_.csv → Estructura bien
# data\430004_XXXX_PresionQFE_.csv → Estructura bien
# data\430009_XXXX_PresionQFE_.csv → Estructura bien
# data\450001_XXXX_PresionQFE_.csv → Estructura bien
# data\450004_XXXX_PresionQFE_.csv → Estructura bien
# data\450005_XXXX_PresionQFE_.csv → Estructura bien
# data\460001_XXXX_PresionQFE_.csv → Estructura mal
# data\470001_XXXX_PresionQFE_.csv → Estructura bien
# data\510005_XXXX_PresionQFE_.csv → Estructura bien
# data\520006_XXXX_PresionQFE_.csv → Estructura bien
# data\530005_XXXX_PresionQFE_.csv → Estructura bien
# data\550001_XXXX_PresionQFE_.csv → Estructura bien
# data\950001_XXXX_PresionQFE_.csv → Estructura bien
# data\950002_XXXX_PresionQFE_.csv → Estructura bien
# data\950003_XXXX_PresionQFE_.csv → Estructura bien
# Archivo consolidado guardado en: data/PresionQFE_consolidado.csv
# Unificando CSVs: PuntoRocio
# ['CodigoNacional', 'momento', 'Td_Valor']
# data\200006_XXXX_PuntoRocio_.csv → Estructura bien
# data\220002_XXXX_PuntoRocio_.csv → Estructura bien
# data\230001_XXXX_PuntoRocio_.csv → Estructura bien
# data\270001_XXXX_PuntoRocio_.csv → Estructura bien
# data\270008_XXXX_PuntoRocio_.csv → Estructura bien
# data\290004_XXXX_PuntoRocio_.csv → Estructura bien
# data\320041_XXXX_PuntoRocio_.csv → Estructura bien
# data\320051_XXXX_PuntoRocio_.csv → Estructura bien
# data\330007_XXXX_PuntoRocio_.csv → Estructura bien
# data\330019_XXXX_PuntoRocio_.csv → Estructura bien
# data\330020_XXXX_PuntoRocio_.csv → Estructura bien
# data\330021_XXXX_PuntoRocio_.csv → Estructura bien
# data\330030_XXXX_PuntoRocio_.csv → Estructura bien
# data\330031_XXXX_PuntoRocio_.csv → Estructura bien
# data\330066_XXXX_PuntoRocio_.csv → Estructura bien
# data\330077_XXXX_PuntoRocio_.csv → Estructura bien
# data\330111_XXXX_PuntoRocio_.csv → Estructura bien
# data\330112_XXXX_PuntoRocio_.csv → Estructura bien
# data\330113_XXXX_PuntoRocio_.csv → Estructura bien
# data\340031_XXXX_PuntoRocio_.csv → Estructura bien
# data\360011_XXXX_PuntoRocio_.csv → Estructura bien
# data\360019_XXXX_PuntoRocio_.csv → Estructura bien
# data\360042_XXXX_PuntoRocio_.csv → Estructura bien
# data\370033_XXXX_PuntoRocio_.csv → Estructura bien
# data\380029_XXXX_PuntoRocio_.csv → Estructura bien
# data\390006_XXXX_PuntoRocio_.csv → Estructura mal
# data\400009_XXXX_PuntoRocio_.csv → Estructura bien
# data\410005_XXXX_PuntoRocio_.csv → Estructura bien
# data\420014_XXXX_PuntoRocio_.csv → Estructura bien
# data\430002_XXXX_PuntoRocio_.csv → Estructura bien
# data\430004_XXXX_PuntoRocio_.csv → Estructura bien
# data\430009_XXXX_PuntoRocio_.csv → Estructura bien
# data\450001_XXXX_PuntoRocio_.csv → Estructura bien
# data\450004_XXXX_PuntoRocio_.csv → Estructura bien
# data\450005_XXXX_PuntoRocio_.csv → Estructura bien
# data\460001_XXXX_PuntoRocio_.csv → Estructura bien
# data\470001_XXXX_PuntoRocio_.csv → Estructura bien
# data\510005_XXXX_PuntoRocio_.csv → Estructura bien
# data\520006_XXXX_PuntoRocio_.csv → Estructura bien
# data\530005_XXXX_PuntoRocio_.csv → Estructura bien
# data\550001_XXXX_PuntoRocio_.csv → Estructura bien
# data\950001_XXXX_PuntoRocio_.csv → Estructura bien
# data\950002_XXXX_PuntoRocio_.csv → Estructura bien
# data\950003_XXXX_PuntoRocio_.csv → Estructura bien
# Archivo consolidado guardado en: data/PuntoRocio_consolidado.csv
# Unificando CSVs: TMaxima
# ['CodigoNacional', 'momento', 'TxPM_Valor', 'FechaHora_Valor']
# data\200006_XXXX_TMaxima_.csv → Estructura bien
# data\220002_XXXX_TMaxima_.csv → Estructura bien
# data\230001_XXXX_TMaxima_.csv → Estructura bien
# data\270001_XXXX_TMaxima_.csv → Estructura bien
# data\270008_XXXX_TMaxima_.csv → Estructura bien
# data\290004_XXXX_TMaxima_.csv → Estructura bien
# data\320041_XXXX_TMaxima_.csv → Estructura bien
# data\320051_XXXX_TMaxima_.csv → Estructura bien
# data\330007_XXXX_TMaxima_.csv → Estructura bien
# data\330019_XXXX_TMaxima_.csv → Estructura bien
# data\330020_XXXX_TMaxima_.csv → Estructura bien
# data\330021_XXXX_TMaxima_.csv → Estructura bien
# data\330030_XXXX_TMaxima_.csv → Estructura bien
# data\330031_XXXX_TMaxima_.csv → Estructura bien
# data\330066_XXXX_TMaxima_.csv → Estructura bien
# data\330077_XXXX_TMaxima_.csv → Estructura bien
# data\330111_XXXX_TMaxima_.csv → Estructura bien
# data\330112_XXXX_TMaxima_.csv → Estructura bien
# data\330113_XXXX_TMaxima_.csv → Estructura bien
# data\340031_XXXX_TMaxima_.csv → Estructura bien
# data\360011_XXXX_TMaxima_.csv → Estructura bien
# data\360019_XXXX_TMaxima_.csv → Estructura bien
# data\360042_XXXX_TMaxima_.csv → Estructura bien
# data\370033_XXXX_TMaxima_.csv → Estructura bien
# data\380029_XXXX_TMaxima_.csv → Estructura bien
# data\390006_XXXX_TMaxima_.csv → Estructura bien
# data\400009_XXXX_TMaxima_.csv → Estructura bien
# data\410005_XXXX_TMaxima_.csv → Estructura bien
# data\420014_XXXX_TMaxima_.csv → Estructura bien
# data\430002_XXXX_TMaxima_.csv → Estructura bien
# data\430004_XXXX_TMaxima_.csv → Estructura mal
# data\430009_XXXX_TMaxima_.csv → Estructura bien
# data\450001_XXXX_TMaxima_.csv → Estructura bien
# data\450004_XXXX_TMaxima_.csv → Estructura bien
# data\450005_XXXX_TMaxima_.csv → Estructura bien
# data\460001_XXXX_TMaxima_.csv → Estructura bien
# data\470001_XXXX_TMaxima_.csv → Estructura bien
# data\510005_XXXX_TMaxima_.csv → Estructura bien
# data\520006_XXXX_TMaxima_.csv → Estructura bien
# data\530005_XXXX_TMaxima_.csv → Estructura bien
# data\550001_XXXX_TMaxima_.csv → Estructura bien
# data\950001_XXXX_TMaxima_.csv → Estructura bien
# data\950002_XXXX_TMaxima_.csv → Estructura bien
# data\950003_XXXX_TMaxima_.csv → Estructura bien
# Archivo consolidado guardado en: data/TMaxima_consolidado.csv
# Unificando CSVs: TMinima
# ['CodigoNacional', 'momento', 'TnAM_Valor', 'FechaHora_Valor']
# data\200006_XXXX_TMinima_.csv → Estructura bien
# data\220002_XXXX_TMinima_.csv → Estructura bien
# data\230001_XXXX_TMinima_.csv → Estructura bien
# data\270001_XXXX_TMinima_.csv → Estructura bien
# data\270008_XXXX_TMinima_.csv → Estructura bien
# data\290004_XXXX_TMinima_.csv → Estructura bien
# data\320041_XXXX_TMinima_.csv → Estructura bien
# data\320051_XXXX_TMinima_.csv → Estructura bien
# data\330007_XXXX_TMinima_.csv → Estructura bien
# data\330019_XXXX_TMinima_.csv → Estructura bien
# data\330020_XXXX_TMinima_.csv → Estructura bien
# data\330021_XXXX_TMinima_.csv → Estructura bien
# data\330030_XXXX_TMinima_.csv → Estructura bien
# data\330031_XXXX_TMinima_.csv → Estructura bien
# data\330066_XXXX_TMinima_.csv → Estructura bien
# data\330077_XXXX_TMinima_.csv → Estructura bien
# data\330111_XXXX_TMinima_.csv → Estructura bien
# data\330112_XXXX_TMinima_.csv → Estructura bien
# data\330113_XXXX_TMinima_.csv → Estructura bien
# data\340031_XXXX_TMinima_.csv → Estructura bien
# data\360011_XXXX_TMinima_.csv → Estructura bien
# data\360019_XXXX_TMinima_.csv → Estructura bien
# data\360042_XXXX_TMinima_.csv → Estructura bien
# data\370033_XXXX_TMinima_.csv → Estructura bien
# data\380029_XXXX_TMinima_.csv → Estructura bien
# data\390006_XXXX_TMinima_.csv → Estructura bien
# data\400009_XXXX_TMinima_.csv → Estructura bien
# data\410005_XXXX_TMinima_.csv → Estructura bien
# data\420014_XXXX_TMinima_.csv → Estructura bien
# data\430002_XXXX_TMinima_.csv → Estructura bien
# data\430004_XXXX_TMinima_.csv → Estructura bien
# data\430009_XXXX_TMinima_.csv → Estructura bien
# data\450001_XXXX_TMinima_.csv → Estructura bien
# data\450004_XXXX_TMinima_.csv → Estructura bien
# data\450005_XXXX_TMinima_.csv → Estructura bien
# data\460001_XXXX_TMinima_.csv → Estructura bien
# data\470001_XXXX_TMinima_.csv → Estructura bien
# data\510005_XXXX_TMinima_.csv → Estructura bien
# data\520006_XXXX_TMinima_.csv → Estructura bien
# data\530005_XXXX_TMinima_.csv → Estructura bien
# data\550001_XXXX_TMinima_.csv → Estructura bien
# data\950001_XXXX_TMinima_.csv → Estructura bien
# data\950002_XXXX_TMinima_.csv → Estructura bien
# data\950003_XXXX_TMinima_.csv → Estructura bien
# Archivo consolidado guardado en: data/TMinima_consolidado.csv
# Unificando CSVs: IndiceUVB
# ['CodigoNacional', 'momento', 'IUV_Valor']
# data\230001_XXXX_IndiceUVB_.csv → Estructura bien
# data\270001_XXXX_IndiceUVB_.csv → Estructura bien
# data\270008_XXXX_IndiceUVB_.csv → Estructura bien
# data\290004_XXXX_IndiceUVB_.csv → Estructura bien
# data\330020_XXXX_IndiceUVB_.csv → Estructura bien
# data\330021_XXXX_IndiceUVB_.csv → Estructura bien
# data\330077_XXXX_IndiceUVB_.csv → Estructura bien
# data\340031_XXXX_IndiceUVB_.csv → Estructura bien
# data\360011_XXXX_IndiceUVB_.csv → Estructura bien
# data\360019_XXXX_IndiceUVB_.csv → Estructura bien
# data\360042_XXXX_IndiceUVB_.csv → Estructura bien
# data\370033_XXXX_IndiceUVB_.csv → Estructura bien
# data\380029_XXXX_IndiceUVB_.csv → Estructura bien
# data\410005_XXXX_IndiceUVB_.csv → Estructura bien
# data\450004_XXXX_IndiceUVB_.csv → Estructura bien
# data\520006_XXXX_IndiceUVB_.csv → Estructura bien
# data\950001_XXXX_IndiceUVB_.csv → Estructura bien
# Archivo consolidado guardado en: data/IndiceUVB_consolidado.csv

# %%
# Revisión de estructuras de csv consolidados generados

for concepto, archivos in archivos_por_concepto_flag.items():
    
    print("Revisando: ", concepto)
    ruta = f"data/{concepto}_consolidado.csv"

    df = pd.read_csv(ruta, delimiter=";")

    print("\n", df.dtypes, "\n")
# Out:
# Revisando:  DiarioTs
#
#  CodigoNacional      int64
# momento            object
# MediaCli_Valor    float64
# MediaAri_Valor    float64
# NumDatos_Valor    float64
# Ts00_Valor        float64
# Ts12_Valor        float64
# Maxima_Valor      float64
# FechaMax_Valor    float64
# Minima_Valor      float64
# FechaMin_Valor    float64
# FechaPro_Valor    float64
# dtype: object
#
# Revisando:  Humedad
#
#  CodigoNacional      int64
# momento            object
# HR_Valor          float64
# dtype: object
#
# Revisando:  PresionQFF
#
#  CodigoNacional      int64
# momento            object
# QFF_Valor         float64
# dtype: object
#
# Revisando:  Temperatura
#
#  CodigoNacional      int64
# momento            object
# Ts_Valor          float64
# dtype: object
#
# Revisando:  Viento
#
#  CodigoNacional      int64
# momento            object
# dd_Valor          float64
# ff_Valor          float64
# VRB_Valor         float64
# dtype: object
#
# Revisando:  Agua24Horas
#
#  CodigoNacional      int64
# momento            object
# RRR24_Valor       float64
# Traza_Valor       float64
# dtype: object
#
# Revisando:  Agua6Horas
#
#  CodigoNacional      int64
# momento            object
# RRR6_Valor        float64
# Traza_Valor       float64
# dtype: object
#
# Revisando:  DiarioRR
#
#  CodigoNacional      int64
# momento            object
# Total_Valor       float64
# Traza_Valor       float64
# Parcial_Valor     float64
# NumDatos_Valor    float64
# FechaPro_Valor    float64
# dtype: object
#
# Revisando:  PresionQFE
#
#  CodigoNacional      int64
# momento            object
# QFE_Valor         float64
# dtype: object
#
# Revisando:  PuntoRocio
#
#  CodigoNacional      int64
# momento            object
# Td_Valor          float64
# dtype: object
#
# Revisando:  TMaxima
#
#  CodigoNacional       int64
# momento             object
# TxPM_Valor         float64
# FechaHora_Valor     object
# dtype: object
#
# Revisando:  TMinima
#
#  CodigoNacional       int64
# momento             object
# TnAM_Valor         float64
# FechaHora_Valor     object
# dtype: object
#
# Revisando:  IndiceUVB
#
#  CodigoNacional      int64
# momento            object
# IUV_Valor         float64
# dtype: object
